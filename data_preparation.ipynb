# %%
# !pip install -q mutagen

# %% [markdown]
# ### Clean the dataset

# %%
from pathlib import Path
import os
import re
import pandas as pd
import math
import statistics

ROOT = Path("./all_data").resolve()

# Define allowed audio file extensions
ALLOWED_EXTS = {".wav", ".mp3", ".flac", ".m4a", ".ogg", ".aac", ".csv"}

print("Scanning root:", ROOT)
# Out:
# Scanning root: /Users/jago/Desktop/naturalis/data_code/all_data

# %% [markdown]
# ### Remove wrong file extension names

# %%
pattern = re.compile(r"(\.(wav|mp3|flac|m4a|ogg|aac))\?.*?$", re.IGNORECASE)

renamed = []

for f in ROOT.rglob("*"):
    if f.is_file():
        match = pattern.search(f.name)
        if match:
            new_name = re.sub(r"\?.*$", "", f.name)
            new_path = f.with_name(new_name)
            if not new_path.exists():
                f.rename(new_path)
                renamed.append((f.name, new_name))

print(f"Renamed {len(renamed)} files")
if renamed:
    print("Example renames:")
    for old, new in renamed[:10]:
        print(" ", old, "→", new)
# Out:
# Renamed 3804 files
# Example renames:
#   1076423.mp3?1717453221 → 1076423.mp3
#   1581050.wav?1753435098 → 1581050.wav
#   1551847.m4a?1751483931 → 1551847.m4a
#   1151253.wav?1722685643 → 1151253.wav
#   1042369.mp3?1715920450 → 1042369.mp3
#   1077567.m4a?1717506924 → 1077567.m4a
#   451895.mp3?1653594683 → 451895.mp3
#   1075749.m4a?1717423713 → 1075749.m4a
#   71729.m4a?1587307780 → 71729.m4a
#   488976.m4a?1656808456 → 488976.m4a

# %%
to_delete = []

for f in ROOT.rglob("*"):
    if f.is_file():
        ext = f.suffix.lower()
        if ext not in ALLOWED_EXTS:
            to_delete.append(f)

print(f"Found {len(to_delete)} non-audio files")

# Uncomment this block to actually delete
for f in to_delete:
    try:
        # print(f) to check first, if you are sure, then do the next line
        os.remove(f)
    except Exception as e:
        print("Error deleting", f, e)

print("Deleted non-audio files ✅")
# Out:
# Found 648 non-audio files
# Deleted non-audio files ✅

# %%
# Try to import mutagen for duration reading (no decoding required)
try:
    from mutagen import File as MutagenFile
    HAVE_MUTAGEN = True
except Exception:
    HAVE_MUTAGEN = False

HAVE_MUTAGEN

# Get combined durations of recordings
def is_hidden(p: Path) -> bool:
    return p.name.startswith(".")

def hms(seconds: float) -> str:
    """Convert seconds → HH:MM:SS (rounded)."""
    if seconds is None or (isinstance(seconds, float) and math.isnan(seconds)):
        return "00:00:00"
    seconds = int(round(seconds))
    h = seconds // 3600
    m = (seconds % 3600) // 60
    s = seconds % 60
    return f"{h:02d}:{m:02d}:{s:02d}"

def get_duration_seconds(path: Path):
    """Return duration using mutagen if available, else None."""
    if not HAVE_MUTAGEN:
        return None
    try:
        m = MutagenFile(path.as_posix())
        if m is None:
            return None
        dur = getattr(m.info, "length", None)
        return float(dur) if dur is not None else None
    except Exception:
        return None

# %%
records = []  # (rel_path, class, ext, duration_seconds)

species_dirs = sorted([p for p in ROOT.iterdir() if p.is_dir() and not is_hidden(p)])
len(species_dirs), [d.name for d in species_dirs]  # quick peek
# Out:
# (54,
#  ['Alytes_almogavarii',
#   'Alytes_cisternasii',
#   'Alytes_dickhilleni',
#   'Alytes_muletensis',
#   'Alytes_obstetricans',
#   'Bombina_bombina',
#   'Bombina_variegata',
#   'Bufo_bufo',
#   'Bufo_spinosus',
#   'Bufotes_balearicus',
#   'Bufotes_boulengeri',
#   'Bufotes_cypriensis',
#   'Bufotes_oblongus',
#   'Bufotes_viridis',
#   'Epidalea_calamita',
#   'Hyla',
#   'Hyla_arborea',
#   'Hyla_intermedia',
#   'Hyla_meridionalis',
#   'Hyla_molleri',
#   'Hyla_orientalis',
#   'Hyla_sarda',
#   'Hyla_savignyi',
#   'Hyperolius_concolor',
#   'Lithobates_catesbeianus',
#   'Mystery_mystery',
#   'Pelobates_cultripes',
#   'Pelobates_fuscus',
#   'Pelobates_vespertinus',
#   'Pelodytes_atlanticus',
#   'Pelodytes_hespericus',
#   'Pelodytes_ibericus',
#   'Pelodytes_punctatus',
#   'Pelophylax',
#   "Pelophylax_'esculentus'",
#   "Pelophylax_'grafi'",
#   'Pelophylax_bedriagae',
#   'Pelophylax_bergeri',
#   'Pelophylax_cretensis',
#   'Pelophylax_cypriensis',
#   'Pelophylax_epeiroticus',
#   'Pelophylax_esculentus',
#   'Pelophylax_kurtmuelleri',
#   'Pelophylax_lessonae',
#   'Pelophylax_perezi',
#   'Pelophylax_ridibundus',
#   'Rana_arvalis',
#   'Rana_dalmatina',
#   'Rana_italica',
#   'Rana_latastei',
#   'Rana_macrocnemis',
#   'Rana_temporaria',
#   'Sonus_naturalis',
#   'unknown'])

# %%
for species_dir in species_dirs:
    cls = species_dir.name  # species label == folder name
    # scan recursively under each species folder
    for f in species_dir.rglob("*"):
        if f.is_file() and (f.suffix.lower() in ALLOWED_EXTS) and not is_hidden(f):
            rel = f.relative_to(ROOT).as_posix()
            ext = f.suffix.lower()
            dur = get_duration_seconds(f)
            records.append((rel, cls, ext, dur))

len(records)
# Out:
# 6824

# %%
df = pd.DataFrame(records, columns=["path", "class", "ext", "duration_seconds"])
display(df.head())
# Out:
#                                                 path               class  \
# 0                      Alytes_almogavarii/396614.m4a  Alytes_almogavarii
# 1                      Alytes_almogavarii/198483.m4a  Alytes_almogavarii
# 2                      Alytes_almogavarii/707099.m4a  Alytes_almogavarii
# 3  Alytes_almogavarii/XC971001-ALYALM030125MixPre...  Alytes_almogavarii
# 4                      Alytes_almogavarii/781699.m4a  Alytes_almogavarii
#
#     ext  duration_seconds
# 0  .m4a         10.820499
# 1  .m4a         15.627029
# 2  .m4a         10.123900
# 3  .wav         52.343946
# 4  .m4a         18.947483

# %%
summary = (
    df.groupby("class")["duration_seconds"]
      .agg(
          n_recordings="count",
          total_seconds=lambda x: sum(d for d in x if d is not None and not math.isnan(d)),
          mean_seconds=lambda x: statistics.mean(d for d in x if d is not None and not math.isnan(d)),
          median_seconds=lambda x: statistics.median(d for d in x if d is not None and not math.isnan(d))
      )
      .reset_index()
)

summary["total_hhmmss"] = summary["total_seconds"].apply(hms)
summary = summary[["class", "n_recordings", "total_seconds", "total_hhmmss", "mean_seconds", "median_seconds"]]

display(summary.head(10))
# Out:
#                  class  n_recordings  total_seconds total_hhmmss  \
# 0   Alytes_almogavarii            18     663.132847     00:11:03
# 1   Alytes_cisternasii            24    1895.613227     00:31:36
# 2   Alytes_dickhilleni            10    1448.538571     00:24:09
# 3    Alytes_muletensis             2     192.828396     00:03:13
# 4  Alytes_obstetricans           428   13938.665894     03:52:19
# 5      Bombina_bombina           597   16789.168814     04:39:49
# 6    Bombina_variegata           139    5633.808328     01:33:54
# 7            Bufo_bufo           250   35236.839721     09:47:17
# 8        Bufo_spinosus            18     477.444849     00:07:57
# 9   Bufotes_balearicus             1      47.256000     00:00:47
#
#    mean_seconds  median_seconds
# 0     36.840714       26.248998
# 1     78.983884       46.550292
# 2    144.853857      135.454649
# 3     96.414198       96.414198
# 4     32.566976       23.182367
# 5     28.122561       19.147687
# 6     40.530995       17.242177
# 7    140.947359       14.795650
# 8     26.524714       17.701833
# 9     47.256000       47.256000

# %%
# Display just species, number of recordings, and total seconds
print(summary[["class", "n_recordings", "total_seconds"]].to_string(index=False))

# Save the 3-column summary to a CSV file
short_summary = summary[["class", "n_recordings", "total_seconds"]]
out_path = ROOT / "species_recording_counts.csv"
short_summary.to_csv(out_path, index=False)

print(f"Saved summary to: {out_path}")
# Out:
#                   class  n_recordings  total_seconds
#      Alytes_almogavarii            18     663.132847
#      Alytes_cisternasii            24    1895.613227
#      Alytes_dickhilleni            10    1448.538571
#       Alytes_muletensis             2     192.828396
#     Alytes_obstetricans           428   13938.665894
#         Bombina_bombina           597   16789.168814
#       Bombina_variegata           139    5633.808328
#               Bufo_bufo           250   35236.839721
#           Bufo_spinosus            18     477.444849
#      Bufotes_balearicus             1      47.256000
#      Bufotes_boulengeri             1      99.516644
#      Bufotes_cypriensis             3      50.536010
#        Bufotes_oblongus             1      14.604250
#         Bufotes_viridis           407   11980.044464
#       Epidalea_calamita           485   18448.420615
#                    Hyla             2     109.056000
#            Hyla_arborea           853   27901.142677
#         Hyla_intermedia           182    3919.648132
#       Hyla_meridionalis           315   13838.733860
#            Hyla_molleri            44    1481.163665
#         Hyla_orientalis            57   34335.923253
#              Hyla_sarda            40    1641.814938
#           Hyla_savignyi            12     578.569034
#     Hyperolius_concolor             5    1103.958125
# Lithobates_catesbeianus            19     547.715228
#         Mystery_mystery            21     454.133303
#     Pelobates_cultripes             7     117.810208
#        Pelobates_fuscus            46    2252.185303
#   Pelobates_vespertinus             6      64.392223
#    Pelodytes_atlanticus            14     419.655069
#    Pelodytes_hespericus             1      54.705875
#      Pelodytes_ibericus            64    7166.422385
#     Pelodytes_punctatus           119    5979.020177
#              Pelophylax           693   16667.815160
# Pelophylax_'esculentus'            90    5173.841701
#      Pelophylax_'grafi'             1      61.946485
#    Pelophylax_bedriagae             4     832.027234
#      Pelophylax_bergeri             1      70.846213
#    Pelophylax_cretensis             1      33.574671
#   Pelophylax_cypriensis             3      52.618639
#  Pelophylax_epeiroticus             9     160.297974
#   Pelophylax_esculentus            79    1822.981597
# Pelophylax_kurtmuelleri            28    1246.669372
#     Pelophylax_lessonae           199    7907.766211
#       Pelophylax_perezi           277   28078.642176
#   Pelophylax_ridibundus           587   25085.014310
#            Rana_arvalis           172    8503.158174
#          Rana_dalmatina            94    4451.733279
#            Rana_italica             1      20.472000
#           Rana_latastei             4     229.986599
#        Rana_macrocnemis             3     165.063968
#         Rana_temporaria           301  191219.080882
#         Sonus_naturalis             5    1448.980838
#                 unknown             1      36.246009
# Saved summary to: /Users/jago/Desktop/naturalis/data_code/all_data/species_recording_counts.csv

# %% [markdown]
# ### Read the cleaned dataset and continue

# %%
from pathlib import Path
import os
import re
import pandas as pd
import math
import statistics

ROOT = Path("./all_data").resolve()
print("Scanning root:", ROOT)
# Out:
# Scanning root: /Users/jago/Desktop/naturalis/data_code/all_data

# %%
records = []  # (rel_path, class, ext, duration_seconds)

species_dirs = sorted([p for p in ROOT.iterdir() if p.is_dir()])
len(species_dirs), [d.name for d in species_dirs]  # quick peek
# Out:
# (54,
#  ['Alytes_almogavarii',
#   'Alytes_cisternasii',
#   'Alytes_dickhilleni',
#   'Alytes_muletensis',
#   'Alytes_obstetricans',
#   'Bombina_bombina',
#   'Bombina_variegata',
#   'Bufo_bufo',
#   'Bufo_spinosus',
#   'Bufotes_balearicus',
#   'Bufotes_boulengeri',
#   'Bufotes_cypriensis',
#   'Bufotes_oblongus',
#   'Bufotes_viridis',
#   'Epidalea_calamita',
#   'Hyla',
#   'Hyla_arborea',
#   'Hyla_intermedia',
#   'Hyla_meridionalis',
#   'Hyla_molleri',
#   'Hyla_orientalis',
#   'Hyla_sarda',
#   'Hyla_savignyi',
#   'Hyperolius_concolor',
#   'Lithobates_catesbeianus',
#   'Mystery_mystery',
#   'Pelobates_cultripes',
#   'Pelobates_fuscus',
#   'Pelobates_vespertinus',
#   'Pelodytes_atlanticus',
#   'Pelodytes_hespericus',
#   'Pelodytes_ibericus',
#   'Pelodytes_punctatus',
#   'Pelophylax',
#   "Pelophylax_'esculentus'",
#   "Pelophylax_'grafi'",
#   'Pelophylax_bedriagae',
#   'Pelophylax_bergeri',
#   'Pelophylax_cretensis',
#   'Pelophylax_cypriensis',
#   'Pelophylax_epeiroticus',
#   'Pelophylax_esculentus',
#   'Pelophylax_kurtmuelleri',
#   'Pelophylax_lessonae',
#   'Pelophylax_perezi',
#   'Pelophylax_ridibundus',
#   'Rana_arvalis',
#   'Rana_dalmatina',
#   'Rana_italica',
#   'Rana_latastei',
#   'Rana_macrocnemis',
#   'Rana_temporaria',
#   'Sonus_naturalis',
#   'unknown'])

# %%
for species_dir in species_dirs:
    cls = species_dir.name  # species label == folder name
    # scan recursively under each species folder
    for f in species_dir.rglob("*"):
        if f.is_file():
            rel = f.relative_to(ROOT).as_posix()
            ext = f.suffix.lower()
            dur = get_duration_seconds(f)
            records.append((rel, cls, ext, dur))

len(records)
# Out:
# 6824

# %%
df = pd.DataFrame(records, columns=["path", "class", "ext", "duration_seconds"])
display(df.head())
# Out:
#                                                 path               class  \
# 0                      Alytes_almogavarii/396614.m4a  Alytes_almogavarii
# 1                      Alytes_almogavarii/198483.m4a  Alytes_almogavarii
# 2                      Alytes_almogavarii/707099.m4a  Alytes_almogavarii
# 3  Alytes_almogavarii/XC971001-ALYALM030125MixPre...  Alytes_almogavarii
# 4                      Alytes_almogavarii/781699.m4a  Alytes_almogavarii
#
#     ext  duration_seconds
# 0  .m4a         10.820499
# 1  .m4a         15.627029
# 2  .m4a         10.123900
# 3  .wav         52.343946
# 4  .m4a         18.947483

# %% [markdown]
# ### Convert m4a to mp3

# %%
count_m4a = df['ext'].eq('.m4a').sum()
print("m4a count:", count_m4a)
# Out:
# m4a count: 1885
# 0       .m4a
# 1       .m4a
# 2       .m4a
# 3       .wav
# 4       .m4a
#         ...
# 6819    .wav
# 6820    .mp3
# 6821    .wav
# 6822    .wav
# 6823    .mp3
# Name: ext, Length: 6824, dtype: object

# %%
# !pip install pydub
# Out:
# Requirement already satisfied: pydub in /opt/anaconda3/lib/python3.11/site-packages (0.25.1)

# %%
from pydub import AudioSegment

converted = 0
for f in ROOT.rglob("*.m4a"):
    mp3_path = f.with_suffix(".mp3")
    if not mp3_path.exists():  # skip if already converted
        sound = AudioSegment.from_file(f, format="m4a")
        sound.export(mp3_path, format="mp3", bitrate="320k")
        converted += 1

print(f"Converted {converted} files to MP3 ✅")
# Out:
# Converted 1885 files to MP3 ✅

# %%
for f in ROOT.rglob("*.m4a"):
    f.unlink() # delete original m4a file
# Out:
# m4a count: 1885

# %% [markdown]
# ### Mono vs stereo sound

# %% [markdown]
# count occurences of mono vs stereo

# %%
from mutagen import File as MutagenFile
from pathlib import Path

ROOT = Path("./all_data").resolve()
mono, stereo = 0, 0

for f in ROOT.rglob("*.*"):
    try:
        m = MutagenFile(f)
        ch = getattr(m.info, "channels", None)
        if ch == 1:
            mono += 1
        elif ch == 2:
            stereo += 1
    except Exception:
        pass

print(f"Mono: {mono}  |  Stereo: {stereo}")
# Out:
# Mono: 3846  |  Stereo: 2890

# %% [markdown]
# convert stereo -> mono

# %%
for f in ROOT.rglob("*"):
    if f.is_file():
        try:
            audio = AudioSegment.from_file(f)
            if audio.channels == 2:  # stereo
                print(f"Converting to mono → {f.name}")
                mono_audio = audio.set_channels(1)
                # overwrite original file safely
                mono_audio.export(f, format=f.suffix.lower().replace('.', ''), bitrate="320k")
                converted += 1
        except Exception as e:
            print("Error with", f, ":", e)

print(f"\n✅ Converted {converted} stereo files to mono")
# Out:
# Error with /Users/jago/Desktop/naturalis/data_code/all_data/species_recording_counts.csv : Decoding failed. ffmpeg returned error code: 183
#
# Output from ffmpeg/avlib:
#
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.6)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 0x132f06260] Error opening input: Invalid data found when processing input
# Error opening input file /Users/jago/Desktop/naturalis/data_code/all_data/species_recording_counts.csv.
# Error opening input files: Invalid data found when processing input
#
# Error with /Users/jago/Desktop/naturalis/data_code/all_data/species_counts.csv : Decoding failed. ffmpeg returned error code: 183
#
# Output from ffmpeg/avlib:
#
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.6)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 0x14d7063e0] Error opening input: Invalid data found when processing input
# Error opening input file /Users/jago/Desktop/naturalis/data_code/all_data/species_counts.csv.
# Error opening input files: Invalid data found when processing input
#
# Error with /Users/jago/Desktop/naturalis/data_code/all_data/combined_list_files.csv : Decoding failed. ffmpeg returned error code: 183
#
# Output from ffmpeg/avlib:
#
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.6)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 0x14d005930] Error opening input: Invalid data found when processing input
# Error opening input file /Users/jago/Desktop/naturalis/data_code/all_data/combined_list_files.csv.
# Error opening input files: Invalid data found when processing input
#
# Error with /Users/jago/Desktop/naturalis/data_code/all_data/species_counts_by_source.csv : Decoding failed. ffmpeg returned error code: 183
#
# Output from ffmpeg/avlib:
#
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.6)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 0x13cf063e0] Error opening input: Invalid data found when processing input
# Error opening input file /Users/jago/Desktop/naturalis/data_code/all_data/species_counts_by_source.csv.
# Error opening input files: Invalid data found when processing input
#
# Error with /Users/jago/Desktop/naturalis/data_code/all_data/species_counts_pivot.csv : Decoding failed. ffmpeg returned error code: 183
#
# Output from ffmpeg/avlib:
#
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.6)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [in#0 @ 0x14260fe90] Error opening input: Invalid data found when processing input
# Error opening input file /Users/jago/Desktop/naturalis/data_code/all_data/species_counts_pivot.csv.
# Error opening input files: Invalid data found when processing input
#
# Converting to mono → 587388.mp3
# Converting to mono → 1077141.mp3
# Converting to mono → XC899305-240430_003XC.mp3
# Converting to mono → 59847.mp3
# Converting to mono → XC899785-240501_004XC.mp3
# Converting to mono → XC899304-240430_002XC.mp3
# Converting to mono → 1577983.mp3
# Converting to mono → 1504808.mp3
# Converting to mono → 1501964.mp3
# Converting to mono → 504657.mp3
# Converting to mono → XC423309-Fire-bellied Toad.mp3
# Converting to mono → XC899784-240501_003XC.mp3
# Converting to mono → 38676.mp3
# Converting to mono → 263034.mp3
# Converting to mono → 1042370.mp3
# Converting to mono → 781441.mp3
# Converting to mono → XC487052-170605Gelbbauchunke Bombina variegata FH 1659.mp3
# Converting to mono → 1074006.mp3
# Converting to mono → 1551847.mp3
# Converting to mono → 41878.mp3
# Converting to mono → 1561204.mp3
# Converting to mono → 833004.mp3
# Converting to mono → 829741.wav
# Converting to mono → XC1041537-250730-Bombina-variegata-1.wav
# Converting to mono → XC570907-LS_30492.mp3
# Converting to mono → 302948.mp3
# Converting to mono → 816066.mp3
# Converting to mono → 758670.mp3
# Converting to mono → 896630.wav
# Converting to mono → XC899782-240501_001XC.mp3
# Converting to mono → 1202490.mp3
# Converting to mono → 1100439.mp3
# Converting to mono → 207793.mp3
# Converting to mono → 782556.mp3
# Converting to mono → 263006.mp3
# Converting to mono → 1068620.mp3
# Converting to mono → 421332.mp3
# Converting to mono → 1042368.mp3
# Converting to mono → 1042369.mp3
# Converting to mono → XC1041538-250730-Bombina-variegata-2.wav
# Converting to mono → 1076423.mp3
# Converting to mono → 1582726.mp3
# Converting to mono → 504659.mp3
# Converting to mono → 504658.mp3
# Converting to mono → XC894130-Bombina_variegata_chant_Ru_du_Proinge_18h08_02_06_2022_for_XC.mp3
# Converting to mono → 1075749.mp3
# Converting to mono → 1506881.wav
# Converting to mono → XC901955-XC-2024-05-11-(984)-TASCAM-Turbastall-Gelbbauchunke-norm--3db.mp3
# Converting to mono → XC899306-240430_005XC.mp3
# Converting to mono → 1466466.mp3
# Converting to mono → XC894129-Bombina_variegata_chant_Ru_de_Proinge_16h33_03_06_2022_for_XC.mp3
# Converting to mono → 117867.wav
# Converting to mono → XC1041539-250730-Bombina-variegata-3.wav
# Converting to mono → 293132.wav
# Converting to mono → 935399.mp3
# Converting to mono → XC962086-Common-Toad-22-apr-TNP.wav
# Converting to mono → XC883719-ZOOM0004BBB.mp3
# Converting to mono → XC974126-rospo4_masseria_180225-120708.mp3
# Converting to mono → XC978664-rospo_macchia_070325-130312.mp3
# Converting to mono → 79798.mp3
# Converting to mono → 1360057.mp3
# Converting to mono → 44196.mp3
# Converting to mono → 34459.mp3
# Converting to mono → 79017.mp3
# Converting to mono → 293238.mp3
# Converting to mono → 1362534.mp3
# Converting to mono → XC1020490-64994.mp3
# Converting to mono → XC883423-ZOOM0003BBB.wav
# Converting to mono → XC899262-240430_2058B-Knarrig-groda.mp3
# Converting to mono → 948758.mp3
# Converting to mono → 1324000.mp3
# Converting to mono → XC883717-ZOOM0004BA.mp3
# Converting to mono → 1556037.mp3
# Converting to mono → XC883362-ZOOM0001BB.mp3
# Converting to mono → 53773.mp3
# Converting to mono → 934323.mp3
# Converting to mono → 622830.mp3
# Converting to mono → XC938900-rospi_vpasso_4mar2017_DR0000_1165(2).wav
# Converting to mono → 192482.wav
# Converting to mono → 1556036.mp3
# Converting to mono → 197397.mp3
# Converting to mono → 1488665.mp3
# Converting to mono → 1488671.mp3
# Converting to mono → 392393.mp3
# Converting to mono → 1488670.mp3
# Converting to mono → XC883408-ZOOM0002A.mp3
# Converting to mono → XC974122-rospo1_mas_250218-120951.mp3
# Converting to mono → 193624.mp3
# Converting to mono → 932247.mp3
# Converting to mono → 1488672.mp3
# Converting to mono → 18930.mp3
# Converting to mono → 1488666.mp3
# Converting to mono → 933400.mp3
# Converting to mono → XC1020491-64995.mp3
# Converting to mono → XC883421-ZOOM0002BA.mp3
# Converting to mono → 935475.mp3
# Converting to mono → XC892024-Bufo-bufo+Porzana-porzana-190503_002,-ночь,-Широкундыш,-тростники,ч.2,AABf.mp3
# Converting to mono → XC883410-ZOOM0002BBA.mp3
# Converting to mono → 1350913.mp3
# Converting to mono → 6888.mp3
# Converting to mono → 158223.mp3
# Converting to mono → 199521.mp3
# Converting to mono → XC938898-rospo_vpasso_4mar2017_DR0000_1166.wav
# Converting to mono → 392368.mp3
# Converting to mono → 7571.mp3
# Converting to mono → 380546.mp3
# Converting to mono → XC883718-ZOOM0004BBA.mp3
# Converting to mono → 6900.mp3
# Converting to mono → XC979122-indeterminé_foret_xenocanto.mp3
# Converting to mono → XC891734-0542.mp3
# Converting to mono → 956245.mp3
# Converting to mono → 1350920.mp3
# Converting to mono → XC899104-Vanlig-padda,-sång,--2024-04-28,-19,58--Glivarpa-mosse.mp3
# Converting to mono → 1350897.mp3
# Converting to mono → 896626.wav
# Converting to mono → 34784.mp3
# Converting to mono → 94526.mp3
# Converting to mono → XC883411-ZOOM0002BBB.wav
# Converting to mono → 34785.mp3
# Converting to mono → XC883409-ZOOM0002BA.mp3
# Converting to mono → 361199.mp3
# Converting to mono → XC974801-ERDKRÖTEN--29.03.2011--Egelsee--17_57--LS100806.wav
# Converting to mono → XC972711-ERDKRÖTEN-im-Egelsee--27.03.2011--7_19--LS100794.wav
# Converting to mono → XC974124-rospo2_mas_250218-120951.mp3
# Converting to mono → XC883420-ZOOM0003A.mp3
# Converting to mono → XC965638-Rospo.mp3
# Converting to mono → XC979703-Bufo-bufo-11-12.05.2018,-Хмелёвка-голоса,рассвет,-A1.mp3
# Converting to mono → XC883552-240314_002ErdkroeteXC.mp3
# Converting to mono → 18929.mp3
# Converting to mono → 245837.mp3
# Converting to mono → 67253.mp3
# Converting to mono → XC974121-rospit_mas_250218-120951.mp3
# Converting to mono → 1350891.mp3
# Converting to mono → 42628.mp3
# Converting to mono → 426460.mp3
# Converting to mono → XC1010361-20120318_1141_Bufo-bufo_M-song_Dabrowa-G_VN860206.wav
# Converting to mono → 122354.mp3
# Converting to mono → XC949867-BUFBUF_220413_1533_PNRBSN_Routot27_B208B.mp3
# Converting to mono → 25659.mp3
# Converting to mono → 159839.mp3
# Converting to mono → 631074.mp3
# Converting to mono → 334502.mp3
# Converting to mono → 82899.mp3
# Converting to mono → XC1010362-20120318_1145_Bufo-bufo_M-song_Dabrowa-G_VN860209.wav
# Converting to mono → 913195.mp3
# Converting to mono → 18806.mp3
# Converting to mono → 621927.mp3
# Converting to mono → 359061.mp3
# Converting to mono → 293026.mp3
# Converting to mono → 18807.mp3
# Converting to mono → 179533.mp3
# Converting to mono → 621922.mp3
# Converting to mono → XC883422-ZOOM0003BBA.mp3
# Converting to mono → 359059.mp3
# Converting to mono → 798357.mp3
# Converting to mono → 236191.wav
# Converting to mono → 132127.mp3
# Converting to mono → 159590.mp3
# Converting to mono → XC979702-Bufo-bufo-11-12.05.2018,-Хмелёвка-голоса,рассвет,-A.mp3
# Converting to mono → 305638.wav
# Converting to mono → 621923.mp3
# Converting to mono → XC892019-Bufo-bufo+Porzana-porzana-190503_002,-ночь,-Широкундыш,-тростники,ч.2,AAB.mp3
# Converting to mono → 18802.mp3
# Converting to mono → 283463.wav
# Converting to mono → XC883358-ZOOM0001BA.mp3
# Converting to mono → XC949868-BUFBUF_220413_1534_PNRBSN_Routot27_B208.mp3
# Converting to mono → XC883923-XC715570---Erdkroete.mp3
# Converting to mono → XC883716-ZOOM0004A.mp3
# Converting to mono → XC883355-ZOOM0001AAB.mp3
# Converting to mono → XC974127-rospo6_mas_250218-120951.mp3
# Converting to mono → 645493.mp3
# Converting to mono → 1369490.mp3
# Converting to mono → 18801.mp3
# Converting to mono → 1307425.mp3
# Converting to mono → 369718.mp3
# Converting to mono → XC976233-Bufo-bufo_agresive-call-in-hand-male_210225_Torrejón-el-Rubio_2137.wav
# Converting to mono → 373790.mp3
# Converting to mono → 886321.wav
# Converting to mono → 372793.mp3
# Converting to mono → XC976235-Bufo-bufo_agresive-call-in-hand-male_210225_Torrejón-el-Rubio_another_1_2138.wav
# Converting to mono → XC934310-Alymul-19970610_Dat17_T1900.wav
# Converting to mono → 246599.mp3
# Converting to mono → 1434019.wav
# Converting to mono → 45841.mp3
# Converting to mono → 104470.mp3
# Converting to mono → 1499910.mp3
# Converting to mono → 230989.mp3
# Converting to mono → 1052465.mp3
# Converting to mono → 1016582.mp3
# Converting to mono → 1434018.wav
# Converting to mono → 1499534.mp3
# Converting to mono → 106676.mp3
# Converting to mono → 1498574.mp3
# Converting to mono → 36528.mp3
# Converting to mono → 1437801.mp3
# Converting to mono → 247109.mp3
# Converting to mono → 100205.mp3
# Converting to mono → 242218.wav
# Converting to mono → 257520.mp3
# Converting to mono → 1498600.mp3
# Converting to mono → 254015.mp3
# Converting to mono → 100198.mp3
# Converting to mono → 1435384.mp3
# Converting to mono → 1499907.mp3
# Converting to mono → 1499912.mp3
# Converting to mono → 1499906.mp3
# Converting to mono → 203819.mp3
# Converting to mono → 1471935.mp3
# Converting to mono → 38664.mp3
# Converting to mono → 312647.mp3
# Converting to mono → 4800.mp3
# Converting to mono → 1498563.mp3
# Converting to mono → 1498567.mp3
# Converting to mono → 1071640.mp3
# Converting to mono → 313011.mp3
# Converting to mono → 324871.mp3
# Converting to mono → 7470.mp3
# Converting to mono → 1010731.mp3
# Converting to mono → 727396.mp3
# Converting to mono → 1498605.mp3
# Converting to mono → 101917.mp3
# Converting to mono → 107369.mp3
# Converting to mono → 8390.mp3
# Converting to mono → 1499916.mp3
# Converting to mono → 1460381.mp3
# Converting to mono → 208578.mp3
# Converting to mono → 44782.mp3
# Converting to mono → 1018797.mp3
# Converting to mono → 1502712.mp3
# Converting to mono → 7471.mp3
# Converting to mono → 746966.mp3
# Converting to mono → 1002485.mp3
# Converting to mono → 235957.mp3
# Converting to mono → 1498558.mp3
# Converting to mono → 100029.mp3
# Converting to mono → 45850.mp3
# Converting to mono → 327957.mp3
# Converting to mono → 1395145.mp3
# Converting to mono → 1516956.mp3
# Converting to mono → 115593.mp3
# Converting to mono → 165920.mp3
# Converting to mono → 1499928.mp3
# Converting to mono → 1429769.mp3
# Converting to mono → 211994.mp3
# Converting to mono → 1516957.mp3
# Converting to mono → 1439793.mp3
# Converting to mono → 1498607.mp3
# Converting to mono → 57474.mp3
# Converting to mono → 7472.mp3
# Converting to mono → 621929.mp3
# Converting to mono → 247873.mp3
# Converting to mono → 1497440.mp3
# Converting to mono → 20894.mp3
# Converting to mono → 979655.mp3
# Converting to mono → 135427.mp3
# Converting to mono → 1081677.mp3
# Converting to mono → 77462.mp3
# Converting to mono → 94935.mp3
# Converting to mono → 1061542.mp3
# Converting to mono → 1470109.mp3
# Converting to mono → 96879.mp3
# Converting to mono → 94934.mp3
# Converting to mono → 208521.mp3
# Converting to mono → 21396.mp3
# Converting to mono → 1455175.mp3
# Converting to mono → 6520.mp3
# Converting to mono → 1439468.mp3
# Converting to mono → 9161.mp3
# Converting to mono → 198029.mp3
# Converting to mono → 244885.mp3
# Converting to mono → 205326.wav
# Converting to mono → 28373.mp3
# Converting to mono → 1498663.mp3
# Converting to mono → 88660.mp3
# Converting to mono → 1465711.mp3
# Converting to mono → 204331.mp3
# Converting to mono → 971182.mp3
# Converting to mono → 94923.mp3
# Converting to mono → 9566.mp3
# Converting to mono → 28372.mp3
# Converting to mono → 974373.mp3
# Converting to mono → 680364.mp3
# Converting to mono → 330877.mp3
# Converting to mono → 117509.mp3
# Converting to mono → 974377.mp3
# Converting to mono → 6692.mp3
# Converting to mono → 99783.mp3
# Converting to mono → 174482.mp3
# Converting to mono → 8495.mp3
# Converting to mono → 96881.mp3
# Converting to mono → 1046662.mp3
# Converting to mono → 265734.mp3
# Converting to mono → 96880.mp3
# Converting to mono → 259529.wav
# Converting to mono → 4245.mp3
# Converting to mono → 303328.mp3
# Converting to mono → 967256.mp3
# Converting to mono → 1034746.mp3
# Converting to mono → 139568.mp3
# Converting to mono → 1019950.mp3
# Converting to mono → 309573.mp3
# Converting to mono → 974376.mp3
# Converting to mono → 239395.wav
# Converting to mono → 19545.mp3
# Converting to mono → 1514271.mp3
# Converting to mono → 38212.mp3
# Converting to mono → 144187.mp3
# Converting to mono → 203262.mp3
# Converting to mono → 69739.mp3
# Converting to mono → 974374.mp3
# Converting to mono → 1027880.mp3
# Converting to mono → 260538.mp3
# Converting to mono → 126106.mp3
# Converting to mono → 5818.mp3
# Converting to mono → 1095411.mp3
# Converting to mono → 1551868.mp3
# Converting to mono → 210343.mp3
# Converting to mono → 35669.mp3
# Converting to mono → 28374.mp3
# Converting to mono → 974375.mp3
# Converting to mono → 205438.mp3
# Converting to mono → 199454.mp3
# Converting to mono → 128710.mp3
# Converting to mono → 977318.mp3
# Converting to mono → 131255.mp3
# Converting to mono → 1122260.mp3
# Converting to mono → 1017218.mp3
# Converting to mono → 1427676.mp3
# Converting to mono → 248.mp3
# Converting to mono → 82569.mp3
# Converting to mono → 1061198.mp3
# Converting to mono → 1437115.mp3
# Converting to mono → 206074.mp3
# Converting to mono → 99997.mp3
# Converting to mono → 6104.mp3
# Converting to mono → 303326.mp3
# Converting to mono → 57793.mp3
# Converting to mono → 868355.mp3
# Converting to mono → 256455.mp3
# Converting to mono → 9021.mp3
# Converting to mono → 159708.mp3
# Converting to mono → 1551865.mp3
# Converting to mono → 303327.mp3
# Converting to mono → 1403312.mp3
# Converting to mono → 668201.mp3
# Converting to mono → 962527.mp3
# Converting to mono → 97818.mp3
# Converting to mono → 43122.mp3
# Converting to mono → 45547.mp3
# Converting to mono → 136536.mp3
# Converting to mono → 102687.mp3
# Converting to mono → 302629.mp3
# Converting to mono → 6259.mp3
# Converting to mono → 104237.mp3
# Converting to mono → 1465268.mp3
# Converting to mono → 9022.mp3
# Converting to mono → 299226.mp3
# Converting to mono → 22440.mp3
# Converting to mono → 1489799.mp3
# Converting to mono → 1497438.mp3
# Converting to mono → 424150.wav
# Converting to mono → 138534.mp3
# Converting to mono → 27474.mp3
# Converting to mono → 137808.mp3
# Converting to mono → 1500740.mp3
# Converting to mono → 29698.mp3
# Converting to mono → 1386178.mp3
# Converting to mono → 1429259.mp3
# Converting to mono → 1386187.mp3
# Converting to mono → 6658.mp3
# Converting to mono → 78762.mp3
# Converting to mono → 314852.mp3
# Converting to mono → 480032.wav
# Converting to mono → 1429270.mp3
# Converting to mono → 1386186.mp3
# Converting to mono → 315741.mp3
# Converting to mono → 1386179.mp3
# Converting to mono → 134858.mp3
# Converting to mono → 676818.mp3
# Converting to mono → 81098.mp3
# Converting to mono → 1496290.mp3
# Converting to mono → 6261.mp3
# Converting to mono → 253338.mp3
# Converting to mono → 254125.mp3
# Converting to mono → 135093.wav
# Converting to mono → 9597.mp3
# Converting to mono → 106750.mp3
# Converting to mono → 106744.mp3
# Converting to mono → 303323.mp3
# Converting to mono → 299209.mp3
# Converting to mono → 1073492.wav
# Converting to mono → 1428420.mp3
# Converting to mono → 1470110.mp3
# Converting to mono → 299208.mp3
# Converting to mono → 1386185.mp3
# Converting to mono → 297027.mp3
# Converting to mono → 247010.mp3
# Converting to mono → 86737.mp3
# Converting to mono → 209592.mp3
# Converting to mono → 255574.mp3
# Converting to mono → 1376128.mp3
# Converting to mono → 324831.mp3
# Converting to mono → 330878.mp3
# Converting to mono → 692091.mp3
# Converting to mono → 3157.mp3
# Converting to mono → 258625.mp3
# Converting to mono → 82481.mp3
# Converting to mono → 215080.mp3
# Converting to mono → 138419.mp3
# Converting to mono → 37979.mp3
# Converting to mono → 1499925.mp3
# Converting to mono → 1499924.mp3
# Converting to mono → 1499918.mp3
# Converting to mono → 1496342.mp3
# Converting to mono → 215081.mp3
# Converting to mono → 114290.mp3
# Converting to mono → 1505648.mp3
# Converting to mono → 38040.mp3
# Converting to mono → 215122.mp3
# Converting to mono → 129449.mp3
# Converting to mono → 209735.mp3
# Converting to mono → 235958.mp3
# Converting to mono → 7483.mp3
# Converting to mono → 115832.mp3
# Converting to mono → 130330.mp3
# Converting to mono → 1034847.mp3
# Converting to mono → 107371.mp3
# Converting to mono → 933457.mp3
# Converting to mono → 1499926.mp3
# Converting to mono → 1499927.mp3
# Converting to mono → 1483957.mp3
# Converting to mono → 107370.mp3
# Converting to mono → 7469.mp3
# Converting to mono → 1054156.mp3
# Converting to mono → 315684.mp3
# Converting to mono → 167799.wav
# Converting to mono → 249886.mp3
# Converting to mono → 477225.wav
# Converting to mono → 698596.mp3
# Converting to mono → 1360920.mp3
# Converting to mono → 1076122.mp3
# Converting to mono → 1095242.mp3
# Converting to mono → 298942.mp3
# Converting to mono → 271104.mp3
# Converting to mono → 293368.mp3
# Converting to mono → 68894.mp3
# Converting to mono → 696959.mp3
# Converting to mono → 38053.mp3
# Converting to mono → 130321.mp3
# Converting to mono → 1034665.mp3
# Converting to mono → 996415.mp3
# Converting to mono → 55877.mp3
# Converting to mono → 307125.mp3
# Converting to mono → 230993.mp3
# Converting to mono → 1499922.mp3
# Converting to mono → 67807.mp3
# Converting to mono → 730919.wav
# Converting to mono → 55876.mp3
# Converting to mono → 106731.mp3
# Converting to mono → 9247.mp3
# Converting to mono → 9521.mp3
# Converting to mono → 1434017.wav
# Converting to mono → 397899.mp3
# Converting to mono → 68665.mp3
# Converting to mono → 691979.mp3
# Converting to mono → 130320.mp3
# Converting to mono → 293369.mp3
# Converting to mono → 45244.mp3
# Converting to mono → 84426.mp3
# Converting to mono → 37820.mp3
# Converting to mono → 28294.mp3
# Converting to mono → 1434015.wav
# Converting to mono → 9523.mp3
# Converting to mono → 1499909.mp3
# Converting to mono → 98146.mp3
# Converting to mono → 1073427.wav
# Converting to mono → 1498356.mp3
# Converting to mono → 37216.mp3
# Converting to mono → 1434014.wav
# Converting to mono → 130323.mp3
# Converting to mono → 309254.mp3
# Converting to mono → 1506807.mp3
# Converting to mono → 166008.mp3
# Converting to mono → 880149.mp3
# Converting to mono → 880148.mp3
# Converting to mono → 1281839.wav
# Converting to mono → 327803.mp3
# Converting to mono → 1439387.mp3
# Converting to mono → 1464282.mp3
# Converting to mono → 1500738.mp3
# Converting to mono → 961092.mp3
# Converting to mono → 1358913.mp3
# Converting to mono → 428755.mp3
# Converting to mono → XC1002141-HYLARB_250519_5380_Brenne_PGAT.mp3
# Converting to mono → 1435608.mp3
# Converting to mono → 299528.mp3
# Converting to mono → 1536430.wav
# Converting to mono → 72592.mp3
# Converting to mono → 762593.mp3
# Converting to mono → 200888.mp3
# Converting to mono → 299529.mp3
# Converting to mono → 1389597.mp3
# Converting to mono → XC893797-240405_011XC.mp3
# Converting to mono → 671074.mp3
# Converting to mono → 177070.mp3
# Converting to mono → 670961.mp3
# Converting to mono → 1076128.mp3
# Converting to mono → 1076114.mp3
# Converting to mono → 1013798.mp3
# Converting to mono → 1076116.mp3
# Converting to mono → 705495.mp3
# Converting to mono → 126759.mp3
# Converting to mono → 1464281.mp3
# Converting to mono → 961091.mp3
# Converting to mono → 1120783.mp3
# Converting to mono → 822962.mp3
# Converting to mono → XC537295-2019-05-25 Tierce-Soulaire et Bourg Rainette verte chant.mp3
# Converting to mono → 1506799.mp3
# Converting to mono → XC884818-HYLARB_230419_2806_DAVIAUD85_CoefGobin.mp3
# Converting to mono → 1520415.mp3
# Converting to mono → 464720.wav
# Converting to mono → 160241.mp3
# Converting to mono → 205475.mp3
# Converting to mono → XC1010376-20220429_1956_Hyla-arborea_M-song_Zory_VN860224.wav
# Converting to mono → 744892.wav
# Converting to mono → 1076117.mp3
# Converting to mono → 406109.mp3
# Converting to mono → 1510234.wav
# Converting to mono → 1435578.mp3
# Converting to mono → 3945.mp3
# Converting to mono → XC1050823-LAUBFFRÖSCHE--VOC_250513-6548--LAUBFRÖSCHE--20_50--Illmitz,-Quergass.wav
# Converting to mono → 1389584.mp3
# Converting to mono → 179476.mp3
# Converting to mono → 1431657.mp3
# Converting to mono → 679604.mp3
# Converting to mono → 222144.mp3
# Converting to mono → XC893795-240405_007XC.mp3
# Converting to mono → XC883791-ausXC715886LaubfroschXC.mp3
# Converting to mono → 1362295.mp3
# Converting to mono → 1417294.mp3
# Converting to mono → 1017711.mp3
# Converting to mono → 1001326.wav
# Converting to mono → 734828.wav
# Converting to mono → 1076106.mp3
# Converting to mono → 169510.mp3
# Converting to mono → 1051261.wav
# Converting to mono → XC893794-240405_006XC.mp3
# Converting to mono → XC899105-Lövgrodor-o-klockgrodor,-sång,--2024-04-28,-21,05--Glimminge-mosse.mp3
# Converting to mono → XC883053-Laubfrosch_2023-05-18_Tettnang_Kiesgrube_R05_0022.wav
# Converting to mono → 101531.mp3
# Converting to mono → 1467349.mp3
# Converting to mono → 4218.mp3
# Converting to mono → 1467348.mp3
# Converting to mono → XC984418-Rainette_verte_250324_1140.mp3
# Converting to mono → 122302.mp3
# Converting to mono → 297071.mp3
# Converting to mono → 428751.mp3
# Converting to mono → 263523.mp3
# Converting to mono → 1629672.mp3
# Converting to mono → 974371.mp3
# Converting to mono → 239806.wav
# Converting to mono → 671016.mp3
# Converting to mono → 1417421.mp3
# Converting to mono → 164367.wav
# Converting to mono → 122359.mp3
# Converting to mono → 1433959.mp3
# Converting to mono → 1471559.mp3
# Converting to mono → 199524.mp3
# Converting to mono → 1097558.mp3
# Converting to mono → 1042371.mp3
# Converting to mono → 199525.mp3
# Converting to mono → 1471558.mp3
# Converting to mono → 164366.wav
# Converting to mono → 272058.mp3
# Converting to mono → 1457776.mp3
# Converting to mono → 1480748.mp3
# Converting to mono → 165211.mp3
# Converting to mono → 1417420.mp3
# Converting to mono → 1497546.mp3
# Converting to mono → 255424.mp3
# Converting to mono → 1437109.mp3
# Converting to mono → 1086290.mp3
# Converting to mono → XC999825-HYLARB_250519_5381_Brenne_PGAT.mp3
# Converting to mono → 327932.mp3
# Converting to mono → 1414356.wav
# Converting to mono → 1042373.mp3
# Converting to mono → 421329.mp3
# Converting to mono → 70483.mp3
# Converting to mono → 1042372.mp3
# Converting to mono → 291897.mp3
# Converting to mono → XC989550-Rainette-verte-+.wav
# Converting to mono → XC970863-LAUBFRÖSCHE,-Konzert--21_48--Th.-Weiher--VOC_240624-5547.wav
# Converting to mono → XC884814-HYLARB_230419_2803_DAVIAUD85_CoefGobin.mp3
# Converting to mono → 947197.mp3
# Converting to mono → 34491.wav
# Converting to mono → XC487051-160913 Europäischer Laubfrosch Hyla arborea FH.mp3
# Converting to mono → 963343.mp3
# Converting to mono → 1490160.mp3
# Converting to mono → 252758.mp3
# Converting to mono → XC1014104-rainette_20250626_000000.wav
# Converting to mono → 195293.mp3
# Converting to mono → 747818.mp3
# Converting to mono → 1520499.mp3
# Converting to mono → 958925.mp3
# Converting to mono → 947193.mp3
# Converting to mono → XC922603-LAUBFRÖSCHE--21_45-(21_36)--Thaininger-Weiher--VOC_240624-5547.wav
# Converting to mono → 199522.mp3
# Converting to mono → 199523.mp3
# Converting to mono → XC893659-HYLARB_240405_4044_Campeneac56_LaMotte.mp3
# Converting to mono → 85354.mp3
# Converting to mono → 947192.mp3
# Converting to mono → XC893793-240405_009XC.mp3
# Converting to mono → 1428252.wav
# Converting to mono → 1335027.mp3
# Converting to mono → XC1002317-HYLARB_220411_1507_PNRBSN_B703_XC.mp3
# Converting to mono → 1494471.mp3
# Converting to mono → 242200.mp3
# Converting to mono → 398917.mp3
# Converting to mono → XC767817-Rainette-verte-ricanement-sec.mp3
# Converting to mono → 947190.mp3
# Converting to mono → 463336.mp3
# Converting to mono → 84060.mp3
# Converting to mono → XC998075-Romaine-12.05.25-(1).wav
# Converting to mono → XC991275-hyla_250422_mmosty.wav
# Converting to mono → 1417419.mp3
# Converting to mono → XC1050828-LAUBFFRÖSCHE--VOC_250513-6548--LAUBFRÖSCHE--20_50--Illmitz,-Quergass.wav
# Converting to mono → 1501833.wav
# Converting to mono → 192298.mp3
# Converting to mono → XC1010377-20220429_1958_Hyla-arborea_M-song_Zory_VN860225.wav
# Converting to mono → XC956253-HYLARB_230523_3418_Bellebouche36_XC.mp3
# Converting to mono → 734845.wav
# Converting to mono → 733204.mp3
# Converting to mono → 317310.wav
# Converting to mono → 272508.mp3
# Converting to mono → 45354.mp3
# Converting to mono → 160188.mp3
# Converting to mono → 94256.mp3
# Converting to mono → 1083040.mp3
# Converting to mono → 317311.wav
# Converting to mono → 1414375.wav
# Converting to mono → 704495.mp3
# Converting to mono → XC884816-HYLARB_230419_2805_DAVIAUD85_CoefGobin.mp3
# Converting to mono → 1026403.mp3
# Converting to mono → 272125.mp3
# Converting to mono → XC1010379-20220429_2001_Hyla-arborea_M-song_Zory_VN860226.wav
# Converting to mono → XC989549-Rainette-verte-+-2.wav
# Converting to mono → 661351.mp3
# Converting to mono → 301120.mp3
# Converting to mono → 327167.wav
# Converting to mono → 679252.mp3
# Converting to mono → 127820.mp3
# Converting to mono → 1026367.mp3
# Converting to mono → XC912279-Løvfrø-2002-06-03-Moesgård.mp3
# Converting to mono → 1058691.mp3
# Converting to mono → 327913.mp3
# Converting to mono → 313687.mp3
# Converting to mono → 1478577.mp3
# Converting to mono → 308073.mp3
# Converting to mono → 1329327.wav
# Converting to mono → 1264264.mp3
# Converting to mono → 59155.mp3
# Converting to mono → 657196.mp3
# Converting to mono → 1015179.mp3
# Converting to mono → 1431827.mp3
# Converting to mono → 224774.mp3
# Converting to mono → 323740.mp3
# Converting to mono → 302956.mp3
# Converting to mono → 1097557.mp3
# Converting to mono → 14646.mp3
# Converting to mono → 1471557.mp3
# Converting to mono → 164369.wav
# Converting to mono → 1431403.mp3
# Converting to mono → 199728.mp3
# Converting to mono → 704493.mp3
# Converting to mono → 177791.mp3
# Converting to mono → 967471.mp3
# Converting to mono → 1074021.mp3
# Converting to mono → 767242.mp3
# Converting to mono → 159863.mp3
# Converting to mono → 971946.mp3
# Converting to mono → XC956254-HYLARB_230612_3490_Lessay50_XC.mp3
# Converting to mono → 164357.wav
# Converting to mono → 658463.mp3
# Converting to mono → XC956250-HYLARB_220504_1874_Careil35_XC.mp3
# Converting to mono → 814072.mp3
# Converting to mono → 155888.mp3
# Converting to mono → 246358.wav
# Converting to mono → 45351.mp3
# Converting to mono → XC1050830-LAUBFRÖSCHE--VOC_250513-6549--LAUBFRÖSCHE--20_56--Illmitz,-Quergasse.wav
# Converting to mono → 1135862.mp3
# Converting to mono → XC998076-Romaine-12.05.25.wav
# Converting to mono → 654258.mp3
# Converting to mono → 655191.mp3
# Converting to mono → 671033.mp3
# Converting to mono → 1474564.mp3
# Converting to mono → 191798.mp3
# Converting to mono → 1624314.mp3
# Converting to mono → 1435588.mp3
# Converting to mono → 1076120.mp3
# Converting to mono → 670996.mp3
# Converting to mono → 7872.mp3
# Converting to mono → XC508147-170905 Hyla arborea Ruf FH 1736.mp3
# Converting to mono → 734826.wav
# Converting to mono → 1221567.mp3
# Converting to mono → 716636.mp3
# Converting to mono → 252320.mp3
# Converting to mono → 1536136.mp3
# Converting to mono → 743568.mp3
# Converting to mono → 14804.mp3
# Converting to mono → XC893661-HYLARB_240405_4046_Campeneac56_LaMotte.mp3
# Converting to mono → 826514.mp3
# Converting to mono → 1389575.mp3
# Converting to mono → 256147.mp3
# Converting to mono → 237585.mp3
# Converting to mono → 671055.mp3
# Converting to mono → 734827.wav
# Converting to mono → 169509.mp3
# Converting to mono → 1497316.mp3
# Converting to mono → 89106.mp3
# Converting to mono → 1076109.mp3
# Converting to mono → 1435589.mp3
# Converting to mono → 7871.mp3
# Converting to mono → 1637495.mp3
# Converting to mono → 1058792.mp3
# Converting to mono → 27758.mp3
# Converting to mono → 1435602.mp3
# Converting to mono → 160117.mp3
# Converting to mono → 124769.mp3
# Converting to mono → 1499098.mp3
# Converting to mono → 94752.mp3
# Converting to mono → 1499099.mp3
# Converting to mono → 255115.mp3
# Converting to mono → 160116.mp3
# Converting to mono → XC939251-hyla_241009_dles.wav
# Converting to mono → 830349.mp3
# Converting to mono → 1138067.mp3
# Converting to mono → 7870.mp3
# Converting to mono → 1439388.mp3
# Converting to mono → 315199.wav
# Converting to mono → 1435571.mp3
# Converting to mono → 1128933.mp3
# Converting to mono → 1435559.mp3
# Converting to mono → 429120.mp3
# Converting to mono → 172435.wav
# Converting to mono → 14383.mp3
# Converting to mono → 1435607.mp3
# Converting to mono → 671085.mp3
# Converting to mono → XC893792-240405_001XC.mp3
# Converting to mono → 745877.mp3
# Converting to mono → 743547.mp3
# Converting to mono → 743546.mp3
# Converting to mono → XC922763-LAUBFRÖSCHE--22_10--Thaininger-Weiher--VOC_240624-5550.wav
# Converting to mono → 180795.mp3
# Converting to mono → XC938110-Rainette-verte-++.wav
# Converting to mono → 826512.mp3
# Converting to mono → 889497.mp3
# Converting to mono → 1500736.mp3
# Converting to mono → 310060.mp3
# Converting to mono → XC1002617-Lövgrodor,-sång,-2-st--2025-05-19,-21.56--Tueflon-_007.mp3
# Converting to mono → 1080841.mp3
# Converting to mono → 705498.mp3
# Converting to mono → 415180.mp3
# Converting to mono → 172436.wav
# Converting to mono → 1435604.mp3
# Converting to mono → 128169.mp3
# Converting to mono → 218760.mp3
# Converting to mono → 218761.mp3
# Converting to mono → 298149.mp3
# Converting to mono → XC893660-HYLARB_240405_4045_Campeneac56_LaMotte.mp3
# Converting to mono → 172437.wav
# Converting to mono → 621934.mp3
# Converting to mono → 1051955.mp3
# Converting to mono → 1431729.mp3
# Converting to mono → XC893462-Boomkikkers,-Cadzand-camping-Beerostie,-110518,-2234-uur.wav
# Converting to mono → XC915287-Lövgrodor,-spel,-2-st--2024-05-30,-23,09--Knäbäcksdammen.mp3
# Converting to mono → XC982134-250308_6016.wav
# Converting to mono → 293367.mp3
# Converting to mono → XC883051-ZOOM0001BB.mp3
# Converting to mono → XC983150-250312_6030_1.mp3
# Converting to mono → 600471.mp3
# Converting to mono → 600470.mp3
# Converting to mono → XC895239-Kik08_Take00.wav
# Converting to mono → XC983427-250313_6036.mp3
# Converting to mono → XC982238-250309_6021.wav
# Converting to mono → XC883725-ZOOM0150BA.mp3
# Converting to mono → XC883071-ZOOM0003BBA.mp3
# Converting to mono → XC883073-ZOOM0004A.mp3
# Converting to mono → XC982041-ZOOM0002AAAAB.mp3
# Converting to mono → 293366.mp3
# Converting to mono → XC990098-Rana-temporaria-0417_210030б-у-Пеле-на-пруду,-ABBf.wav
# Converting to mono → XC883249-ZOOM0005AAAAAAAAAAB-(1).mp3
# Converting to mono → XC983433-250313_6040.wav
# Converting to mono → 34507.mp3
# Converting to mono → XC983436-250313_6041_1.mp3
# Converting to mono → XC983437-250313_6042.mp3
# Converting to mono → 600473.mp3
# Converting to mono → XC883243-ZOOM0004AAAAAB-(1).mp3
# Converting to mono → XC883933-240322_5431.mp3
# Converting to mono → XC883248-ZOOM0005AAAAAAAAAAAAB-(1).mp3
# Converting to mono → XC983428-250313_6037.mp3
# Converting to mono → XC982237-250309_6020.wav
# Converting to mono → 428270.wav
# Converting to mono → XC883235-ZOOM0003AAAAAAAB-(1).mp3
# Converting to mono → XC883239-ZOOM0003AB-(1).mp3
# Converting to mono → XC982891-ZOOM0010AAAA.mp3
# Converting to mono → 34466.mp3
# Converting to mono → XC883822-240322_5430.mp3
# Converting to mono → XC883222-ZOOM0015A.mp3
# Converting to mono → XC883236-ZOOM0003AAAAAB-(1).mp3
# Converting to mono → XC883252-ZOOM0005AAAAAAB.mp3
# Converting to mono → XC883216-ZOOM0014BBA.mp3
# Converting to mono → XC983432-250313_6039_1.mp3
# Converting to mono → XC983155-250312_6034.mp3
# Converting to mono → XC883261-ZOOM0014AA.mp3
# Converting to mono → 329992.mp3
# Converting to mono → XC979423-250225_5979.mp3
# Converting to mono → 1371773.mp3
# Converting to mono → 605533.mp3
# Converting to mono → 1371772.mp3
# Converting to mono → XC1010359-20120318_1131_Rana-temporaria_M-song_Dąbrowa-G_VN860207.wav
# Converting to mono → 90262.mp3
# Converting to mono → XC883050-ZOOM0001BA.mp3
# Converting to mono → XC1010360-20120318_1133_Rana-temporaria_M-song_Dabrowa-G_VN860208.wav
# Converting to mono → XC983152-250312_6031.mp3
# Converting to mono → XC979481-250226_5981.mp3
# Converting to mono → XC884086-ZOOM0151A20230320082940A.mp3
# Converting to mono → 938451.mp3
# Converting to mono → XC983163-250312_6035_1.mp3
# Converting to mono → XC982042-ZOOM0002AAAB.mp3
# Converting to mono → XC883934-240322_5432.mp3
# Converting to mono → 293028.mp3
# Converting to mono → XC883072-ZOOM0003BBB.wav
# Converting to mono → 1371771.mp3
# Converting to mono → 293029.mp3
# Converting to mono → XC982040-ZOOM0002AAAAA.mp3
# Converting to mono → XC883237-ZOOM0003AAAB-(1).mp3
# Converting to mono → 25627.mp3
# Converting to mono → 66736.mp3
# Converting to mono → XC883054-ZOOM0002BA.mp3
# Converting to mono → XC983144-250312_6025.mp3
# Converting to mono → 795227.mp3
# Converting to mono → 121297.mp3
# Converting to mono → XC883251-ZOOM0004AAAB-(1).mp3
# Converting to mono → XC983142-250312_6023.mp3
# Converting to mono → 6694.mp3
# Converting to mono → 1015758.mp3
# Converting to mono → 6643.mp3
# Converting to mono → XC982632-ZOOM0008B.mp3
# Converting to mono → 174687.mp3
# Converting to mono → XC982236-250309_6019.wav
# Converting to mono → XC983145-250312_6026.mp3
# Converting to mono → XC883255-ZOOM0005B.mp3
# Converting to mono → XC979422-250225_5978.mp3
# Converting to mono → XC982894-ZOOM0010B.mp3
# Converting to mono → XC892095-Rana-temporaria-дачи-Чеб-190421_005,-AABB.mp3
# Converting to mono → 148829.mp3
# Converting to mono → 297028.mp3
# Converting to mono → 80349.mp3
# Converting to mono → XC983153-250312_6032.mp3
# Converting to mono → XC883211-ZOOM0014A.mp3
# Converting to mono → 126065.mp3
# Converting to mono → XC889792-RANTEM_0803222_GO20_marchiennes_XC.mp3
# Converting to mono → 972869.mp3
# Converting to mono → XC893467-Bruine-Kikker,-lichte-echo,-IGS,-110421,-2311-uur.mp3
# Converting to mono → XC982135-250308_6017.wav
# Converting to mono → XC983440-250313_6044.wav
# Converting to mono → XC982038-ZOOM0001AAAB.mp3
# Converting to mono → XC990100-Rana-temporaria-0417_210030б-у-Пеле-на-пруду,1-1.wav
# Converting to mono → XC983154-250312_6033.mp3
# Converting to mono → 1349477.mp3
# Converting to mono → 35287.mp3
# Converting to mono → XC923197-GRASFRÖSCHE---02.04.2016--Zellsee--12_16---VOC_160404-3904-A.wav
# Converting to mono → XC983146-250312_6027_1.mp3
# Converting to mono → XC893541-CFrog-V04D32b.wav
# Converting to mono → XC983148-250312_6029.mp3
# Converting to mono → XC883240-ZOOM0004AAAAAAAAAAAB-(1).mp3
# Converting to mono → 930494.mp3
# Converting to mono → XC982239-250309_6022.wav
# Converting to mono → XC979347-250224_5969.mp3
# Converting to mono → 654899.mp3
# Converting to mono → XC979554-250226_5984.mp3
# Converting to mono → 222285.mp3
# Converting to mono → XC982043-ZOOM0002AB.mp3
# Converting to mono → XC883543-ZOOM0014BA.mp3
# Converting to mono → XC983143-250312_6024.wav
# Converting to mono → XC893538-CFrog-V04D09.wav
# Converting to mono → 42413.mp3
# Converting to mono → XC979424-250226_5980.mp3
# Converting to mono → XC979348-250225_5973.mp3
# Converting to mono → XC982039-ZOOM0001AB.mp3
# Converting to mono → XC987893-250412_2862-Vanlig-groda.mp3
# Converting to mono → XC892096-Rana-temporaria-дачи-Чеб-190421_005,-AABBf.mp3
# Converting to mono → XC983438-250313_6043.wav
# Converting to mono → 35288.mp3
# Converting to mono → 78968.mp3
# Converting to mono → XC983430-250313_6038.mp3
# Converting to mono → XC979482-250226_5982.mp3
# Converting to mono → XC883277-ZOOM0014BA.mp3
# Converting to mono → XC982637-ZOOM0009B.mp3
# Converting to mono → XC883055-ZOOM0002BBA.mp3
# Converting to mono → XC883213-ZOOM0014BA.mp3
# Converting to mono → 12852.wav
# Converting to mono → 1349480.mp3
# Converting to mono → XC883821-240322_5427.mp3
# Converting to mono → XC883219-ZOOM0014BBB.wav
# Converting to mono → XC883242-ZOOM0004AAAAAAAB-(1).mp3
# Converting to mono → XC883210-ZOOM0013BBB.mp3
# Converting to mono → 957820.mp3
# Converting to mono → XC883585-ZOOM0015AB.mp3
# Converting to mono → XC883247-ZOOM0005AAAAAAAAAAAAAAB-(1).mp3
# Converting to mono → XC883245-ZOOM0004AB-(1).mp3
# Converting to mono → XC883846-MIXPRE09820230321162937A.mp3
# Converting to mono → XC883069-ZOOM0003BA.mp3
# Converting to mono → XC883250-ZOOM0005AAAAAAAAB-(1).mp3
# Converting to mono → 124652.mp3
# Converting to mono → XC982631-ZOOM0008AB.mp3
# Converting to mono → 1325161.mp3
# Converting to mono → XC979224-250225_5972.mp3
# Converting to mono → XC883209-ZOOM0013BBA.mp3
# Converting to mono → XC883059-ZOOM0002BBB.wav
# Converting to mono → XC883108-Frog_Common1_Rana-temporaria_M6MKH-905_StorsjoWetlandCove_Predawn_2ndJune22.mp3
# Converting to mono → 49797.mp3
# Converting to mono → XC982896-ZOOM0011A.mp3
# Converting to mono → XC979349-250225_5974.mp3
# Converting to mono → XC979484-250226_5983.mp3
# Converting to mono → XC883052-ZOOM0002A.mp3
# Converting to mono → XC934436-Sammakko.mp3
# Converting to mono → XC884087-240323_5435.mp3
# Converting to mono → XC883208-ZOOM0013BA.mp3
# Converting to mono → XC982630-ZOOM0008AAAB.mp3
# Converting to mono → XC883068-ZOOM0003A.mp3
# Converting to mono → XC895240-Kik08_Take02.wav
# Converting to mono → XC982633-ZOOM0009AAA.mp3
# Converting to mono → XC883254-ZOOM0005AAB.mp3
# Converting to mono → 1369483.mp3
# Converting to mono → XC896465-240415_2034-Okänd-groda.mp3
# Converting to mono → XC982133-ZOOM0004AB.mp3
# Converting to mono → XC982892-ZOOM0010AAAB.mp3
# Converting to mono → 1326222.mp3
# Converting to mono → 93149.mp3
# Converting to mono → 33151.wav
# Converting to mono → XC983147-250312_6028_1.mp3
# Converting to mono → XC883241-ZOOM0004AAAAAAAAAB-(1).mp3
# Converting to mono → 164360.mp3
# Converting to mono → XC883246-ZOOM0005AAAAAAAAAAAAAAAA-(1).mp3
# Converting to mono → XC883075-ZOOM0004BA.mp3
# Converting to mono → XC990099-Rana-temporaria-0417_210030б-у-Пеле-на-пруду,-ABB.wav
# Converting to mono → XC982235-250309_6018.wav
# Converting to mono → XC883544-ZOOM0015AAA.mp3
# Converting to mono → 33150.wav
# Converting to mono → 291754.mp3
# Converting to mono → XC982636-ZOOM0009AB.mp3
# Converting to mono → XC883076-ZOOM0004BBA.mp3
# Converting to mono → XC883253-ZOOM0005AAAAB.mp3
# Converting to mono → XC893539-CFrog-V04D24.wav
# Converting to mono → XC982893-ZOOM0010AAB.mp3
# Converting to mono → XC982634-ZOOM0009AAB.mp3
# Converting to mono → 944790.mp3
# Converting to mono → XC883394-STE-016.mp3
# Converting to mono → XC615875-201213_002o.mp3
# Converting to mono → XC883389-STE-004b.mp3
# Converting to mono → XC884976-STE-011.wav
# Converting to mono → XC883393-STE-013.mp3
# Converting to mono → XC884980-STE-012.mp3
# Converting to mono → XC883386-STE-003.mp3
# Converting to mono → XC914827-Pelobates-vespertinus-240614_013,-D.wav
# Converting to mono → XC914823-Pelobates-vespertinus-240614_013,-D1.wav
# Converting to mono → XC914828-Pelobates-vespertinus-240614_013,-D1.mp3
# Converting to mono → 709251.mp3
# Converting to mono → 768060.mp3
# Converting to mono → XC975753-Hyla-molleri-(online-audio-converter.com).mp3
# Converting to mono → XC1001431-Hyla-molleri_song_180525_Fuente-de-los-Portugueses_2218.wav
# Converting to mono → 637141.mp3
# Converting to mono → 626020.wav
# Converting to mono → 626021.wav
# Converting to mono → 899329.mp3
# Converting to mono → 626022.wav
# Converting to mono → XC975756-Voz-065-(online-audio-converter.com).mp3
# Converting to mono → XC962359-hyla-molleri-2-laguito-del-maíllo-23-06-2018.mp3
# Converting to mono → 649386.mp3
# Converting to mono → 796109.mp3
# Converting to mono → XC416598-LS108997 Woodchat Shrike QQ call A.mp3
# Converting to mono → 1015181.mp3
# Converting to mono → XC884605-220613_20-Hylla-molleri-22.56-Carreirón.mp3
# Converting to mono → XC962358-hyla-molleri-1-laguito-del-maíllo-23-06-2018.mp3
# Converting to mono → 925629.wav
# Converting to mono → XC884736-220917_15-Hyla-molleri-furnas-Sur-13.00-(Basoñas)-.mp3
# Converting to mono → XC1001395-250524_16.-Hylla-molleri-choir-lagoiña-carreiron-22.30-.mp3
# Converting to mono → XC661049-ES-Lu-Viveiro_Audio_2021-07-03_23.30.mp3
# Converting to mono → XC964772-hyla-molleri-3-laguito-del-maíllo-23-06-2018.mp3
# Converting to mono → XC661048-ES-Lu-Viveiro_Video_2021-05-24_23.30.mp3
# Converting to mono → XC884607-210508_03-canto-entre-silveiras-Veiga-de-Pedrafigueira-12.00-prob-Hyla-molleri-Carnota.mp3
# Converting to mono → 165441.mp3
# ...
# Converting to mono → 1441034.mp3
# Converting to mono → 1351929.mp3
# Converting to mono → XC990326-pelophylax-perezi-5-cerca-cerrado-garrido-12-05-2018.mp3
# Converting to mono → XC998649-25051530RanaComun.mp3
# Converting to mono → 204818.mp3
# Converting to mono → XC962342-pelophylax-perezi-1-laguito-del-maíllo-23-06-2018.mp3
# Converting to mono → XC990330-pelophylax-perezi-8-cerca-cerrado-garrido-12-05-2018.mp3
# Converting to mono → 783565.mp3
# Converting to mono → 848153.mp3
# Converting to mono → 472120.mp3
# Converting to mono → 472118.mp3
# Converting to mono → 685514.mp3
# Converting to mono → XC896533-240414-P.-perezi-10.30--Charca-olveira-Corrubedo.mp3
# Converting to mono → 1520578.mp3
# Converting to mono → 1467627.mp3
# Converting to mono → 1063463.mp3
# Converting to mono → 1451800.mp3
# Converting to mono → XC964759-pelophylax-perezi-11-laguito-del-maíllo-23-06-2018.mp3
# Converting to mono → XC884245-14juillet_5h00_murillodegallego_tarente_grenouilles_engoulevent.wav
# Converting to mono → XC962354-pelophylax-perezi-11-laguito-del-maíllo-23-06-2018.mp3
# Converting to mono → 685515.mp3
# Converting to mono → 472119.mp3
# Converting to mono → 720195.mp3
# Converting to mono → 660200.mp3
# Converting to mono → XC1005785-GRANOTA-VERDA160525MixPre-015_RIERA-DEL-MORRAL-(2).wav
# Converting to mono → XC896541-240414_21.-P-perezi-2-males-2-m-apart-song-in-a-pond.-Trasduna-corrubedo.mp3
# Converting to mono → XC933469-pelophylaxs-perezi-3-arroyo-de-la-lavandera-03-06-2024.mp3
# Converting to mono → XC1043650-250924-221846Rã-Verde-Pelophylax-perezi.wav
# Converting to mono → 1305130.wav
# Converting to mono → XC974597-pelophylax-perezi-charca-de-la-rana-suicida-20-02-2025-13-grados.mp3
# Converting to mono → 1547720.mp3
# Converting to mono → 965414.mp3
# Converting to mono → XC1008841-CM-022.mp3
# Converting to mono → XC890057-Pelophylax-perezi_call_270523_Lago-de-Babia.wav
# Converting to mono → 1366858.wav
# Converting to mono → XC933075-pelophylax-perezi-3-charquita-08-06-2024.mp3
# Converting to mono → 99943.mp3
# Converting to mono → XC915336-Strandpaddor,-spel,-1-hane-nära--2024-05-09,-21,49--Svingeln.mp3
# Converting to mono → XC990986-EPICAL_250422_5009_Vinsobre26.mp3
# Converting to mono → 130306.mp3
# Converting to mono → 172860.mp3
# Converting to mono → 201017.mp3
# Converting to mono → 46179.mp3
# Converting to mono → 379345.mp3
# Converting to mono → 197556.mp3
# Converting to mono → 379344.mp3
# Converting to mono → 1068510.mp3
# Converting to mono → 124776.mp3
# Converting to mono → 611743.mp3
# Converting to mono → 1305129.wav
# Converting to mono → XC893974-240406_008XC.wav
# Converting to mono → 944950.mp3
# Converting to mono → 629816.mp3
# Converting to mono → 151062.mp3
# Converting to mono → XC973360-epidalea-calamita-guadalbarbo-12-02-2025-10-grados.mp3
# Converting to mono → XC893975-240406_009XC.wav
# Converting to mono → 204408.mp3
# Converting to mono → 21644.mp3
# Converting to mono → XC990987-EPICAL_250422_5010_Vinsobre26.mp3
# Converting to mono → 236337.mp3
# Converting to mono → 126823.mp3
# Converting to mono → 21645.mp3
# Converting to mono → 204409.mp3
# Converting to mono → XC893484-Rugstreeppadden,-Edesche-Heide,-260622,-2358-uur-(2).wav
# Converting to mono → 209501.mp3
# Converting to mono → XC890062-Epidaela-calamita_calls-of-an-handling-male_180223_Valdoncina.wav
# Converting to mono → 629817.mp3
# Converting to mono → XC883321-Toad,-Natterjack-Holme-2.5.2001-SF.2.mp3
# Converting to mono → 1076117.mp3
# Converting to mono → 130328.mp3
# Converting to mono → 1316267.mp3
# Converting to mono → 1316273.mp3
# Converting to mono → 196667.mp3
# Converting to mono → XC913637-MONO-017_calamite_1.wav
# Converting to mono → 44972.mp3
# Converting to mono → 245097.mp3
# Converting to mono → 13209.mp3
# Converting to mono → XC883678-Toad,-Natterjack-(Holland)-SF-(1).-wav.wav
# Converting to mono → 4187.mp3
# Converting to mono → 1076106.mp3
# Converting to mono → 1076104.mp3
# Converting to mono → 45529.mp3
# Converting to mono → 160087.mp3
# Converting to mono → XC757901-25octobre_16h30.mp3
# Converting to mono → 202447.mp3
# Converting to mono → 245917.mp3
# Converting to mono → XC1000934-2024-05-14_Epidalea-calamita_Bufotes-viridis_Msong_Wery.wav
# Converting to mono → 106538.mp3
# Converting to mono → 37974.mp3
# Converting to mono → XC896195-Rugstreeppad-220315-Kalmthoutse-heide.mp3
# Converting to mono → XC893977-240406_014.mp3
# Converting to mono → 166018.mp3
# Converting to mono → 889502.mp3
# Converting to mono → 131752.mp3
# Converting to mono → 28953.mp3
# Converting to mono → 953692.mp3
# Converting to mono → 582683.mp3
# Converting to mono → 236357.mp3
# Converting to mono → 67880.mp3
# Converting to mono → 582443.mp3
# Converting to mono → 239501.mp3
# Converting to mono → 37992.wav
# Converting to mono → 582682.mp3
# Converting to mono → 129027.mp3
# Converting to mono → 104994.mp3
# Converting to mono → 1008640.mp3
# Converting to mono → 948462.mp3
# Converting to mono → XC923037-2013-06-16_rugstreeppad_Castricum_2035u_GOKeijl.mp3
# Converting to mono → 199321.mp3
# Converting to mono → 85768.mp3
# Converting to mono → 43288.mp3
# Converting to mono → 133914.mp3
# Converting to mono → 239701.mp3
# Converting to mono → 174684.mp3
# Converting to mono → 197735.mp3
# Converting to mono → 1026409.mp3
# Converting to mono → 239310.mp3
# Converting to mono → 85543.mp3
# Converting to mono → 247396.mp3
# Converting to mono → 315601.mp3
# Converting to mono → 209406.mp3
# Converting to mono → 333.mp3
# Converting to mono → 133520.mp3
# Converting to mono → 38398.mp3
# Converting to mono → 1378708.mp3
# Converting to mono → 1378709.mp3
# Converting to mono → 168531.mp3
# Converting to mono → 326.mp3
# Converting to mono → 239671.mp3
# Converting to mono → 95219.mp3
# Converting to mono → XC883679-Toad,-Natterjack-(Holland)-SF-(2).wav.wav
# Converting to mono → 47407.mp3
# Converting to mono → 27126.mp3
# Converting to mono → 127967.mp3
# Converting to mono → XC971909-epidalea-calamita-las-ventillas-24-01-2025-14-grados.mp3
# Converting to mono → XC895196-dat008-007.wav
# Converting to mono → 127972.mp3
# Converting to mono → 127966.mp3
# Converting to mono → 254918.mp3
# Converting to mono → 953682.mp3
# Converting to mono → XC983820-epidalea-calamita-1-arroyo-galapagares-12-03-2025-11-grados.wav
# Converting to mono → 139437.mp3
# Converting to mono → 398916.mp3
# Converting to mono → 128704.mp3
# Error with /Users/jago/Desktop/naturalis/data_code/all_data/Epidalea_calamita/135412.mp3 : Decoding failed. ffmpeg returned error code: 183
#
# Output from ffmpeg/avlib:
#
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.6)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mp3 @ 0x156705d50] Format mp3 detected only with low score of 1, misdetection possible!
# [mp3 @ 0x156705d50] Failed to find two consecutive MPEG audio frames.
# [in#0 @ 0x156705af0] Error opening input: Invalid data found when processing input
# Error opening input file /Users/jago/Desktop/naturalis/data_code/all_data/Epidalea_calamita/135412.mp3.
# Error opening input files: Invalid data found when processing input
#
# Converting to mono → 85372.mp3
# Converting to mono → 197702.mp3
# Converting to mono → 176729.mp3
# Converting to mono → XC883206-2022-04-29_Kreuzkröte-(normale-Rauschreduzierung).mp3
# Converting to mono → 13463.mp3
# Converting to mono → 192860.mp3
# Converting to mono → 254135.mp3
# Converting to mono → 312174.mp3
# Converting to mono → XC902963-Strandpaddor,-spel--2024-05-09,-21,32--Svingeln.mp3
# Converting to mono → XC894092-2024_04_02_Crapaud_Calamite_Rainette_verte_chorus_Loch_ar_stang_21h08_for_XC.mp3
# Converting to mono → XC883830-Epidaela-calamita_3rd-single-male-singing_180223_Valdoncina.wav
# Converting to mono → 26237.mp3
# Converting to mono → XC990990-EPICAL_250422_5012_Vinsobre26.mp3
# Converting to mono → 240195.mp3
# Converting to mono → 56854.mp3
# Converting to mono → 106965.mp3
# Converting to mono → 1408292.mp3
# Converting to mono → 240220.mp3
# Converting to mono → XC884557-Epidalea-calamita-Natterjack-Toad-2008-07-07-2337-Teivenu-karjers-56.407568,-24.343449-(not-seen)-Telinga-5W.wav
# Converting to mono → 237565.wav
# Converting to mono → 95942.mp3
# Converting to mono → 237654.mp3
# Converting to mono → 253852.mp3
# Converting to mono → 7432.mp3
# Converting to mono → 1330235.mp3
# Converting to mono → 94523.mp3
# Converting to mono → 236358.mp3
# Converting to mono → 43051.mp3
# Converting to mono → 236359.mp3
# Converting to mono → 9344.mp3
# Converting to mono → 253853.mp3
# Converting to mono → 1394353.mp3
# Converting to mono → 9346.mp3
# Converting to mono → 1327004.mp3
# Converting to mono → 191835.mp3
# Converting to mono → 43052.mp3
# Converting to mono → 43053.mp3
# Converting to mono → 71787.mp3
# Converting to mono → 199529.mp3
# Converting to mono → 7949.mp3
# Converting to mono → 195893.mp3
# Converting to mono → 1366860.wav
# Converting to mono → 115831.mp3
# Converting to mono → 130327.mp3
# Converting to mono → 144624.wav
# Converting to mono → 241727.wav
# Converting to mono → XC890066-Epidalea-calamita_song-one-male_080623_Perilla-de-Castro_melhor.wav
# Converting to mono → 237584.mp3
# Converting to mono → 1068726.mp3
# Converting to mono → 956018.mp3
# Converting to mono → XC893483-Rugstreeppadden,-Edesche-Heide,-260622,-2358-uur-(1).wav
# Converting to mono → 1221566.mp3
# Converting to mono → 115830.mp3
# Converting to mono → 130326.mp3
# Converting to mono → 1076109.mp3
# Converting to mono → XC913639-MONO-017_calamite-2.wav
# Converting to mono → XC890065-Epidalea-calamita_chorus-singing-males_160224_Antimio-de-Arriba.wav
# Converting to mono → 20625.mp3
# Converting to mono → 951601.mp3
# Converting to mono → 20023.mp3
# Converting to mono → 575262.mp3
# Converting to mono → 23098.mp3
# Converting to mono → 124768.mp3
# Converting to mono → 59913.mp3
# Converting to mono → 166017.mp3
# Converting to mono → 240134.mp3
# Converting to mono → 45527.mp3
# Converting to mono → 944751.mp3
# Converting to mono → 315172.wav
# Converting to mono → 255501.mp3
# Converting to mono → 44403.mp3
# Converting to mono → 197559.mp3
# Converting to mono → 164407.mp3
# Converting to mono → 254965.mp3
# Converting to mono → 38052.mp3
# Converting to mono → 34440.mp3
# Converting to mono → 201676.wav
# Converting to mono → XC890070-Epidalea-calamita_song_240423_Violla.wav
# Converting to mono → XC975749-Voz-063-(online-audio-converter.com).mp3
# Converting to mono → XC912284-2011-06-25-Strandtudse-Grenen-0024-6min.mp3
# Converting to mono → 20025.mp3
# Converting to mono → XC896194-Rugstreeppad-180421-Kalmthoutse-heide.mp3
# Converting to mono → 327288.wav
# Converting to mono → 949713.mp3
# Converting to mono → 932376.mp3
# Converting to mono → 263933.mp3
# Converting to mono → 168541.mp3
# Converting to mono → XC902460-ZOOM0013.mp3
# Converting to mono → 12700.mp3
# Converting to mono → 294542.mp3
# Converting to mono → 1002484.mp3
# Converting to mono → 952677.mp3
# Converting to mono → 296192.mp3
# Converting to mono → 67428.mp3
# Converting to mono → 1552592.mp3
# Converting to mono → 128847.mp3
# Converting to mono → 80360.mp3
# Converting to mono → 947196.mp3
# Converting to mono → 1369172.mp3
# Converting to mono → 896619.wav
# Converting to mono → XC884054-OW19Heinven_ZOOM0002_0075.wav
# Converting to mono → 1360060.mp3
# Converting to mono → 1354528.mp3
# Converting to mono → 1360061.mp3
# Converting to mono → 12678.mp3
# Converting to mono → 651949.mp3
# Converting to mono → 430292.mp3
# Converting to mono → XC937651-Hyla-orientalis--240917_018,-Кашхатау,-опушка,B.mp3
# Converting to mono → XC493071-190504_002,12-00--18-00, Широкундыш, отмель,ч.1,6!!.MP3
# Converting to mono → XC937652-Hyla-orientalis--240917_018,-Кашхатау,-опушка,B1.mp3
# Converting to mono → 49073.mp3
# Converting to mono → 697508.mp3
# Converting to mono → XC900439-Hyla-arborea-240420_005,-В.mp3
# Converting to mono → XC941693-Hyla-savignyi-190404_019,-Лерик-C1.wav
# Converting to mono → XC423307-Fire-belliedToad and GreenTree Frog.mp3
# Converting to mono → XC839805-230505_0191b_KR15_HYLARB_21h00.mp3
# Converting to mono → XC841134-230505_0192a_KR15_HYLARB_23h10.mp3
# Converting to mono → 172750.mp3
# Converting to mono → 1024430.mp3
# Converting to mono → 524318.mp3
# Converting to mono → 260592.wav
# Converting to mono → 1452503.wav
# Converting to mono → 488590.mp3
# Converting to mono → XC840919-230506_0198b.mp3
# Converting to mono → XC840046-230505_0192b_KR15_HYLARB_01h30.mp3
# Converting to mono → 218128.mp3
# Converting to mono → 7151.mp3
# Converting to mono → 854040.mp3
# Converting to mono → 7152.mp3
# Converting to mono → 702632.mp3
# Converting to mono → 195144.wav
# Converting to mono → 1374728.mp3
# Converting to mono → XC937357-Hyla-orientalis-0917_181147,Кашхатау,Телевышка,поля,-1.wav
# Converting to mono → XC937358-Hyla-orientalis-0917_181147,Кашхатау,Телевышка,поля,C.wav
# Converting to mono → XC840917-230506_0198.mp3
# Converting to mono → XC815351-230515_0283a.mp3
# Converting to mono → XC900440-Hyla-arborea-240420_005,-ВВ.mp3
# Converting to mono → XC941692-Hyla-savignyi-190404_019,-Лерик-C2+.wav
# Converting to mono → 171513.wav
# Converting to mono → 50299.mp3
# Converting to mono → XC883893-DCR_0005.mp3
# Converting to mono → XC965617-SOUNDSCAPE-mit-TEICH--u.-LAUBFRÖSCHEN-u.-VÖGELN--21_36--Th.-Weiher--VOC_240624-554.wav
# Converting to mono → XC949866-EPICAL_BUFVIR_BUFBUF_PELFUS_160414_1772_Freyming-Merlebach57.mp3
# Converting to mono → XC1001481-250524_15.-Soundscape-22.30-Hyla-molleri,-T-merula,-E-rubecula,-C-europaeus,-A-platyrrhynchos,-wav.wav
# Converting to mono → XC901693-240509_016XC.wav
# Converting to mono → 896624.wav
# Converting to mono → 587068.wav
# Converting to mono → 1006730.mp3
# Converting to mono → XC537260-2019-04-05 Nice - Maccinaghio Amphibiens divers Corse - rainette sarde berger et pe Crapaud vert.mp3
# Converting to mono → 1006731.mp3
# Converting to mono → XC914249-Hyla-sarda.mp3
# Converting to mono → 354890.mp3
# Converting to mono → XC537269-2019-04-05 Nice - Maccinaghio Rainette sarde +.mp3
# Converting to mono → XC537270-2019-04-05 Nice - Maccinaghio Rainette sarde chant ++ et type crapaud vert.mp3
# Converting to mono → XC800063-Rainette-sarde-chant-++-2.wav
# Converting to mono → XC800064-Rainette-sarde-chant-++-3.wav
# Converting to mono → 9959.mp3
# Converting to mono → XC537271-2019-04-05 Nice - Maccinaghio Rainette sarde chant sature.mp3
# Converting to mono → 1006729.mp3
# Converting to mono → XC537273-2019-04-05 Nice - Maccinaghio Rainette sarde concert nocturne 2.mp3
# Converting to mono → XC914250-Hyla-sarda-lone-male.mp3
# Converting to mono → 832991.mp3
# Converting to mono → XC800065-Rainette-sarde-chant-++.wav
# Converting to mono → XC537274-2019-04-05 Nice - Maccinaghio Rainette sarde concert nocturne.mp3
# Converting to mono → XC883288-Frog,-Levant-Green-Hizir-1-SF-(2).wav
# Converting to mono → XC614899-201213_005k.mp3
# Converting to mono → XC883289-Frog,-Levant-Green-Hizir-1-SF-(1).wav
# Converting to mono → XC883283-Frog,-Levant-Green-(Pelophylax-bedriagae)-Sarımsaklı-8.4.12-SF.mp3
# Converting to mono → XC892051-Bufotes-oblongus-190413_057,Пирасора,Азер-С.mp3
#
# ✅ Converted 4854 stereo files to mono

# %% [markdown]
# ### Deduplication

# %%
import hashlib
def md5_hash(path, chunk_size=8192):
    """Compute MD5 hash of a file in chunks."""
    md5 = hashlib.md5()
    with open(path, "rb") as f:
        while chunk := f.read(chunk_size):
            md5.update(chunk)
    return md5.hexdigest()

records = []
for f in ROOT.rglob("*"):
    if f.is_file():
        try:
            h = md5_hash(f)
            records.append((f.relative_to(ROOT).as_posix(), h))
        except Exception as e:
            print("Error reading:", f, e)

df_md5 = pd.DataFrame(records, columns=["path", "md5"])
df_md5.head()
# Out:
#                            path                               md5
# 0  species_recording_counts.csv  bf4a9fd7caf68e01c9b5c88446b6f098
# 1            species_counts.csv  49cba9f47ecb2d49cacd51cfd00b5b7b
# 2       combined_list_files.csv  6efccdcfbc86c0846878b0a7809c8264
# 3  species_counts_by_source.csv  1e0702270a2fbf14c57d73fb2cbd0eec
# 4      species_counts_pivot.csv  292e9d9d6866e47bc8827a8a6a31ac94

# %%
# Group by hash and find those with >1 occurrence
dupes = df_md5[df_md5.duplicated("md5", keep=False)].sort_values("md5")

if not dupes.empty:
    print(f"Found {dupes['md5'].nunique()} duplicate groups ({len(dupes)} files total).")
else:
    print("No exact duplicates found.")

dupes.head(10)
# Out:
# Found 178 duplicate groups (365 files total).
#                                 path                               md5
# 4660  Pelophylax_lessonae/213335.mp3  01ff2d0c75f9b3f34e86ab95605a0c0b
# 4655  Pelophylax_lessonae/213334.mp3  01ff2d0c75f9b3f34e86ab95605a0c0b
# 6324    Epidalea_calamita/236357.mp3  024408162b5bee7065968b4848e5b06e
# 6509    Epidalea_calamita/236359.mp3  024408162b5bee7065968b4848e5b06e
# 6507    Epidalea_calamita/236358.mp3  024408162b5bee7065968b4848e5b06e
# 3240     Bombina_bombina/1442984.wav  026bd6e05ccef9eb57fb20bbfa21e7c6
# 3295     Bombina_bombina/1442983.wav  026bd6e05ccef9eb57fb20bbfa21e7c6
# 6389    Epidalea_calamita/241373.wav  027e50192b2beade46d50d442ac1ad37
# 6325    Epidalea_calamita/241374.wav  027e50192b2beade46d50d442ac1ad37
# 3347      Bombina_bombina/698104.mp3  047a10d92ee37cdf1f446eff1463837b

# %%
# report duplicated to a file
out_path = ROOT / "duplicate_files_by_md5.csv"
dupes.to_csv(out_path, index=False)
print(f"Duplicate report saved to: {out_path}")
# Out:
# Duplicate report saved to: /Users/jago/Desktop/naturalis/data_code/all_data/duplicate_files_by_md5.csv

# %%
# remove duplicates
# Make sure df_md5 exists (with columns path, md5)
assert "df_md5" in locals(), "Please run the MD5 hashing step first."

# Find duplicates
duplicates = df_md5[df_md5.duplicated("md5", keep=False)]
to_delete = []

for md5_hash, group in duplicates.groupby("md5"):
    files = group["path"].tolist()
    if len(files) > 1:
        # Keep the first file and delete the rest
        keep = files[0]
        remove = files[1:]
        for rel_path in remove:
            f = ROOT / rel_path
            if f.exists():
                to_delete.append(f)

print(f"Found {len(to_delete)} duplicate files to delete.")

# Uncomment to preview instead of deleting
for f in to_delete[:10]:
    print("Would delete:", f)

# --- Actually delete duplicates ---
confirm = input("Type 'yes' to confirm deletion of duplicates: ")
if confirm.lower() == "yes":
    for f in to_delete:
        try:
            f.unlink()
        except Exception as e:
            print("Error deleting", f, ":", e)
    print(f"✅ Deleted {len(to_delete)} duplicate files.")
else:
    print("❌ Deletion cancelled.")
# Out:
# Found 187 duplicate files to delete.
# Would delete: /Users/jago/Desktop/naturalis/data_code/all_data/Pelophylax_lessonae/213335.mp3
# Would delete: /Users/jago/Desktop/naturalis/data_code/all_data/Epidalea_calamita/236358.mp3
# Would delete: /Users/jago/Desktop/naturalis/data_code/all_data/Epidalea_calamita/236359.mp3
# Would delete: /Users/jago/Desktop/naturalis/data_code/all_data/Bombina_bombina/1442983.wav
# Would delete: /Users/jago/Desktop/naturalis/data_code/all_data/Epidalea_calamita/241373.wav
# Would delete: /Users/jago/Desktop/naturalis/data_code/all_data/Bufotes_viridis/698106.mp3
# Would delete: /Users/jago/Desktop/naturalis/data_code/all_data/Hyla_orientalis/31622.mp3
# Would delete: /Users/jago/Desktop/naturalis/data_code/all_data/Pelophylax_perezi/290922.mp3
# Would delete: /Users/jago/Desktop/naturalis/data_code/all_data/Hyla_meridionalis/XC893219-Meridionale-240521.wav
# Would delete: /Users/jago/Desktop/naturalis/data_code/all_data/Pelobates_fuscus/967763.mp3
# ✅ Deleted 187 duplicate files.

# %% [markdown]
# ### Serial recordings

# %%
from datetime import timedelta
import pandas as pd
import numpy as np

# Adjust these paths to your actual folder structure:
BASE = Path(".").resolve()

INAT_OCC = BASE / "iNaturalist" / "occurrence.txt"
OBS_OCC  = BASE / "observation_org" / "occurrence.txt"
XC_META  = BASE / "xeno_canto" / "metadata.csv"

MIN_RECORDS = 50  # species threshold for all three sources

# %%
def load_darwin_occ(occ_path: Path, source_name: str) -> pd.DataFrame:
    """
    Load a Darwin Core occurrence.txt file and return a DataFrame with:
      class, recordedBy, decimalLatitude, decimalLongitude, timestamp, source
    """
    occ = pd.read_csv(occ_path, sep="\t", dtype=str, low_memory=False)
    
    # Make sure expected columns exist
    for col in ["genus", "specificEpithet", "recordedBy",
                "decimalLatitude", "decimalLongitude", "eventDate"]:
        if col not in occ.columns:
            occ[col] = np.nan

    df = pd.DataFrame({
        "gbifID": occ["gbifID"],
        "genus": occ["genus"].astype(str).str.strip(),
        "specificEpithet": occ["specificEpithet"].astype(str).str.strip(),
        "recordedBy": occ["recordedBy"].astype(str).str.strip(),
        "decimalLatitude": pd.to_numeric(occ["decimalLatitude"], errors="coerce"),
        "decimalLongitude": pd.to_numeric(occ["decimalLongitude"], errors="coerce"),
        "eventDate_raw": occ["eventDate"],
    })
    
    # Species label: Genus_species (or just Genus if species missing)
    df["class"] = np.where(
        df["specificEpithet"].notna() & (df["specificEpithet"] != ""),
        df["genus"] + "_" + df["specificEpithet"],
        df["genus"],
    )
    
    # Parse timestamp (UTC); Darwin Core eventDate can be date or datetime
    df["timestamp"] = pd.to_datetime(df["eventDate_raw"], errors="coerce", utc=True)
    
    df["source"] = source_name
    
    # Drop rows with no species at all
    df = df[df["class"].notna() & (df["class"] != "")]
    
    return df[["gbifID", "class", "recordedBy", "decimalLatitude", "decimalLongitude", "timestamp", "source"]]

# %%
def load_xc_metadata(csv_path: Path) -> pd.DataFrame:
    """
    Load Xeno-canto metadata.csv and return:
      class, recordedBy, decimalLatitude, decimalLongitude, timestamp, source
    """
    xc = pd.read_csv(csv_path, dtype=str, low_memory=False)

    # Make sure expected columns exist
    for col in ["gen", "sp", "rec", "lat", "lon", "date", "time", "uploaded"]:
        if col not in xc.columns:
            xc[col] = np.nan

    def combine_datetime(row):
        # Prefer date + time, then date, then uploaded
        if pd.notna(row["date"]) and pd.notna(row["time"]):
            dt = pd.to_datetime(row["date"] + " " + row["time"], errors="coerce", utc=True)
        elif pd.notna(row["date"]):
            dt = pd.to_datetime(row["date"], errors="coerce", utc=True)
        else:
            dt = pd.to_datetime(row["uploaded"], errors="coerce", utc=True)
        return dt

    df = pd.DataFrame({
        "genus": xc["gen"].astype(str).str.strip(),
        "specificEpithet": xc["sp"].astype(str).str.strip(),
        "recordedBy": xc["rec"].astype(str).str.strip(),
        "decimalLatitude": pd.to_numeric(xc["lat"], errors="coerce"),
        "decimalLongitude": pd.to_numeric(xc["lon"], errors="coerce"),
    })
    df["timestamp"] = xc.apply(combine_datetime, axis=1)
    
    df["class"] = np.where(
        df["specificEpithet"].notna() & (df["specificEpithet"] != ""),
        df["genus"] + "_" + df["specificEpithet"],
        df["genus"],
    )

    df["source"] = "xeno_canto"
    df = df[df["class"].notna() & (df["class"] != "")]
    
    return df[["class", "recordedBy", "decimalLatitude", "decimalLongitude", "timestamp", "source"]]

# %%
def detect_serial_for_source(df_source: pd.DataFrame,
                             min_records: int = 100,
                             loc_round_decimals: int = 3) -> tuple[pd.DataFrame, pd.DataFrame]:
    """
    df_source must have columns:
      class, recordedBy, decimalLatitude, decimalLongitude, timestamp, source

    Returns:
      df_marked  - original df_source with columns added:
                   lat_round, lon_round, loc_key, keep_flag, serial_flag
      stats      - per-species summary: total, kept_valid, serial_removed
    """
    df = df_source.copy()

    # Round location and build loc_key
    df["lat_round"] = df["decimalLatitude"].round(loc_round_decimals)
    df["lon_round"] = df["decimalLongitude"].round(loc_round_decimals)
    df["loc_key"] = np.where(
        df["lat_round"].notna() & df["lon_round"].notna(),
        df["lat_round"].astype(str) + "," + df["lon_round"].astype(str),
        np.nan,
    )

    # Species counts in this source
    counts = df.groupby("class").size().rename("n_total").reset_index()
    big_species = counts[counts["n_total"] > min_records]["class"]
    big_species_set = set(big_species)

    # Filter to big species
    df["is_big_species"] = df["class"].isin(big_species_set)

    # Among big species, we can only dedupe when user+loc+time are all present
    mask_valid = (
        df["is_big_species"]
        & df["recordedBy"].notna()
        & df["loc_key"].notna()
        & df["timestamp"].notna()
    )
    df["keep_flag"] = True            # default: keep
    df["serial_flag"] = False         # default: not serial

    def mark_group(g: pd.DataFrame) -> pd.DataFrame:
        """Sliding 1-hour window per (class, user, loc_key) group."""
        g = g.sort_values("timestamp").copy()
        last_kept = None
        keep = []
        for _, row in g.iterrows():
            t = row["timestamp"]
            if pd.isna(t):
                keep.append(True)
                continue
            if last_kept is None or (t - last_kept) >= timedelta(hours=1):
                keep.append(True)
                last_kept = t
            else:
                keep.append(False)
        g["keep_flag"] = keep
        g["serial_flag"] = ~g["keep_flag"]
        return g

    # Apply only on valid subset
    df_valid = df[mask_valid]
    df_others = df[~mask_valid]

    if not df_valid.empty:
        df_marked_valid = (
            df_valid
            .groupby(["class", "recordedBy", "loc_key"], group_keys=False)
            .apply(mark_group)
        )
        # Recombine
        df_marked = pd.concat([df_marked_valid, df_others], ignore_index=True)
    else:
        df_marked = df.copy()

    # Build summary stats for big species
    serial_valid = df_marked[mask_valid & df_marked["serial_flag"]]
    kept_valid = df_marked[mask_valid & df_marked["keep_flag"]]

    removed_counts = serial_valid.groupby("class").size().rename("serial_removed").reset_index()
    kept_counts = kept_valid.groupby("class").size().rename("kept_valid").reset_index()

    stats = counts.merge(kept_counts, on="class", how="left").merge(removed_counts, on="class", how="left")
    stats["kept_valid"] = stats["kept_valid"].fillna(0).astype(int)
    stats["serial_removed"] = stats["serial_removed"].fillna(0).astype(int)

    return df_marked, stats

# %%
df_xc = load_xc_metadata(XC_META)
df_xc_marked, stats_xc = detect_serial_for_source(df_xc, min_records=MIN_RECORDS)

print("Xeno-canto shape:", df_xc_marked.shape)
stats_xc[stats_xc["class"].isin(stats_xc[stats_xc["n_total"] > MIN_RECORDS]["class"])]

# Species where at least 1 serial recording was detected
serial_species_obs = stats_xc[stats_xc["serial_removed"] > 0]["class"].tolist()
serial_species_obs
# Out:
# Xeno-canto shape: (1405, 12)
# []

# %%
df_inat_raw = load_darwin_occ(INAT_OCC, source_name="iNaturalist")
df_inat_marked, stats_inat = detect_serial_for_source(df_inat_raw, min_records=MIN_RECORDS)

print("iNaturalist shape:", df_inat_marked.shape)
stats_inat[stats_inat["class"].isin(stats_inat[stats_inat["n_total"] > MIN_RECORDS]["class"])]

# Species where at least 1 serial recording was detected
serial_species_inat = stats_inat[stats_inat["serial_removed"] > 0]["class"].tolist()
serial_species_inat
# Out:
# iNaturalist shape: (3517, 13)
# /var/folders/_x/lf3w3d_x3hl4yll355z33jnc0000gp/T/ipykernel_42136/2741506372.py:69: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(mark_group)
# ['Alytes_obstetricans',
#  'Bombina_bombina',
#  'Bufo_bufo',
#  'Epidalea_calamita',
#  'Hyla_arborea',
#  'Pelophylax_esculentus',
#  'Pelophylax_nan',
#  'Pelophylax_ridibundus']

# %%
df_obs_raw = load_darwin_occ(OBS_OCC, source_name="observation_org")
df_obs_marked, stats_obs = detect_serial_for_source(df_obs_raw, min_records=MIN_RECORDS)

print("Observation.org shape:", df_obs_marked.shape)
stats_obs[stats_obs["class"].isin(stats_obs[stats_obs["n_total"] > MIN_RECORDS]["class"])]

# Species where at least 1 serial recording was detected
serial_species_obs = stats_obs[stats_obs["serial_removed"] > 0]["class"].tolist()
serial_species_obs
# Out:
# Observation.org shape: (1460, 13)
# /var/folders/_x/lf3w3d_x3hl4yll355z33jnc0000gp/T/ipykernel_42136/2741506372.py:69: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(mark_group)
# ['Alytes_obstetricans',
#  'Epidalea_calamita',
#  'Hyla_arborea',
#  'Pelophylax_lessonae',
#  'Pelophylax_nan',
#  'Pelophylax_ridibundus',
#  'Rana_arvalis']

# %%
serial_obs = df_obs_marked[
    (df_obs_marked["class"].isin(serial_species_obs)) &
    (df_obs_marked["serial_flag"])
].copy()

print(serial_obs.shape)
serial_obs.head()
# Out:
# (68, 13)
#          gbifID                class   recordedBy  decimalLatitude  \
# 28   3720390039  Alytes_obstetricans   User 22575        52.100000
# 114  3714945639  Alytes_obstetricans   User 86447        41.706300
# 174  3719173218    Epidalea_calamita  User 123903        37.203507
# 189  4882072480    Epidalea_calamita    User 1338        52.300000
# 202  3725504100    Epidalea_calamita  User 142165        52.100000
#
#      decimalLongitude                 timestamp           source  lat_round  \
# 28           5.350000 2021-06-05 00:00:00+00:00  observation_org     52.100
# 114          2.401800 2014-04-27 00:00:00+00:00  observation_org     41.706
# 174         -6.170717 2020-12-12 00:00:00+00:00  observation_org     37.204
# 189          5.000000 2024-05-23 00:00:00+00:00  observation_org     52.300
# 202          4.950000 2020-05-09 00:00:00+00:00  observation_org     52.100
#
#      lon_round        loc_key  is_big_species  keep_flag  serial_flag
# 28       5.350      52.1,5.35            True      False         True
# 114      2.402   41.706,2.402            True      False         True
# 174     -6.171  37.204,-6.171            True      False         True
# 189      5.000       52.3,5.0            True      False         True
# 202      4.950      52.1,4.95            True      False         True

# %%
serial_inat = df_inat_marked[
    (df_inat_marked["class"].isin(serial_species_inat)) &
    (df_inat_marked["serial_flag"])
].copy()

print(serial_inat.shape)
serial_inat.head()
# Out:
# (30, 13)
#          gbifID                class     recordedBy  decimalLatitude  \
# 16   4145552338  Alytes_obstetricans   Gloria Arias        41.483051
# 75   5087101769  Alytes_obstetricans       nico1111        45.009510
# 157  4133960301      Bombina_bombina  Philipp Byzov        54.858979
# 185  4901047071      Bombina_bombina       aistespo        55.114031
# 202  5153759368      Bombina_bombina       dfriemel        51.158175
#
#      decimalLongitude                 timestamp       source  lat_round  \
# 16           2.074496 2021-06-06 21:16:54+00:00  iNaturalist     41.483
# 75           2.007085 2024-08-15 22:54:02+00:00  iNaturalist     45.010
# 157         37.594146 2023-06-08 13:27:31+00:00  iNaturalist     54.859
# 185         25.403895 2024-05-18 14:54:55+00:00  iNaturalist     55.114
# 202         14.282224 2025-05-10 19:09:53+00:00  iNaturalist     51.158
#
#      lon_round        loc_key  is_big_species  keep_flag  serial_flag
# 16       2.074   41.483,2.074            True      False         True
# 75       2.007    45.01,2.007            True      False         True
# 157     37.594  54.859,37.594            True      False         True
# 185     25.404  55.114,25.404            True      False         True
# 202     14.282  51.158,14.282            True      False         True

# %%
# get the file names based on gbifID
INAT_mm = BASE / "iNaturalist" / "multimedia.txt"
OBS_mm  = BASE / "observation_org" / "multimedia.txt"

mm_obs = pd.read_csv(OBS_mm, sep="\t", dtype=str, low_memory=False)
mm_inat = pd.read_csv(INAT_mm, sep="\t", dtype=str, low_memory=False)

# Keep only gbifID and identifier URL
mm_obs = mm_obs[["gbifID", "identifier"]].copy()
mm_inat = mm_inat[["gbifID", "identifier"]].copy()

# Clean filename: extract last element of URL and remove query strings
mm_obs["filename"] = (
    mm_obs["identifier"]
      .astype(str)
      .str.split("/").str[-1]
      .str.replace(r"\?.*$", "", regex=True)
)

mm_inat["filename"] = (
    mm_inat["identifier"]
      .astype(str)
      .str.split("/").str[-1]
      .str.replace(r"\?.*$", "", regex=True)
)

serial_obs = serial_obs.merge(mm_obs, on="gbifID", how="left")
serial_inat = serial_inat.merge(mm_inat, on="gbifID", how="left")

# %%
serial_obs.columns
# Out:
# Index(['gbifID', 'class', 'recordedBy', 'decimalLatitude', 'decimalLongitude',
#        'timestamp', 'source', 'lat_round', 'lon_round', 'loc_key',
#        'is_big_species', 'keep_flag', 'serial_flag', 'identifier', 'filename'],
#       dtype='object')

# %%
serial_inal_fns = (
    serial_inat["filename"]
    .dropna()
    .astype(str)
    .str.strip()
    .str.replace(r"\?.*$", "", regex=True)
)

serial_obs_fns = (
    serial_obs["filename"]
    .dropna()
    .astype(str)
    .str.strip()
    .str.replace(r"\?.*$", "", regex=True)
)

serial_filenames = set(serial_inal_fns) | set(serial_obs_fns)
len(serial_filenames)
# Out:
# 103

# %%
ROOT = Path("all_data").resolve()

to_delete_paths = []

for f in ROOT.rglob("*"):
    if f.is_file():
        name = f.name
        if name in serial_filenames:
            to_delete_paths.append(f)

len(to_delete_paths)
# Out:
# 74

# %%
for p in to_delete_paths[:20]:
    print(p)
# Out:
# /Users/jago/Desktop/naturalis/data_code/all_data/Pelophylax/45841.mp3
# /Users/jago/Desktop/naturalis/data_code/all_data/Pelophylax/173808.mp3
# /Users/jago/Desktop/naturalis/data_code/all_data/Pelophylax/305500.mp3
# /Users/jago/Desktop/naturalis/data_code/all_data/Pelophylax/1499912.mp3
# /Users/jago/Desktop/naturalis/data_code/all_data/Pelophylax/324871.mp3
# /Users/jago/Desktop/naturalis/data_code/all_data/Pelophylax/1499928.mp3
# /Users/jago/Desktop/naturalis/data_code/all_data/Pelophylax/94935.mp3
# /Users/jago/Desktop/naturalis/data_code/all_data/Pelophylax/251493.mp3
# /Users/jago/Desktop/naturalis/data_code/all_data/Pelophylax/303326.mp3
# /Users/jago/Desktop/naturalis/data_code/all_data/Pelophylax/299226.mp3
# /Users/jago/Desktop/naturalis/data_code/all_data/Pelophylax/106750.mp3
# /Users/jago/Desktop/naturalis/data_code/all_data/Pelophylax/106744.mp3
# /Users/jago/Desktop/naturalis/data_code/all_data/Pelophylax/1499925.mp3
# /Users/jago/Desktop/naturalis/data_code/all_data/Pelophylax/1499924.mp3
# /Users/jago/Desktop/naturalis/data_code/all_data/Pelophylax/1499918.mp3
# /Users/jago/Desktop/naturalis/data_code/all_data/Pelophylax/311893.wav
# /Users/jago/Desktop/naturalis/data_code/all_data/Pelophylax/130330.mp3
# /Users/jago/Desktop/naturalis/data_code/all_data/Pelophylax/1499926.mp3
# /Users/jago/Desktop/naturalis/data_code/all_data/Pelophylax/311890.wav
# /Users/jago/Desktop/naturalis/data_code/all_data/Pelophylax/136988.mp3

# %%
print(f"About to delete {len(to_delete_paths)} files from {ROOT}")

confirm = input("Type 'yes' to confirm deletion: ")

if confirm.lower() == "yes":
    deleted = 0
    errors = 0
    for p in to_delete_paths:
        try:
            p.unlink()
            deleted += 1
        except Exception as e:
            print("Error deleting", p, ":", e)
            errors += 1
    print(f"✅ Deleted {deleted} files. Errors: {errors}")
else:
    print("❌ Deletion cancelled.")
# Out:
# About to delete 74 files from /Users/jago/Desktop/naturalis/data_code/all_data
# ✅ Deleted 74 files. Errors: 0

# %% [markdown]
# ### Split the data

# %%
import random
from pathlib import Path
import shutil

# Root folder with species subfolders
root = Path("all_data").resolve()          # adjust if needed

# Where to put the splits
out_root = Path("dataset_splits").resolve()
train_dir = out_root / "train"
val_dir   = out_root / "val"
test_dir  = out_root / "test"

for d in [train_dir, val_dir, test_dir]:
    d.mkdir(parents=True, exist_ok=True)

# Only these species
target_species = {
    "Rana_latastei",
    "Pelodytes_atlanticus",
    "Bufo_spinosus",
    "Lithobates_catesbeianus",
    "Hyla_savignyi",
    "Alytes_almogavarii",
    "Pelophylax_bedriagae",
    "Pelophylax_kurtmuelleri",
    "Alytes_dickhilleni",
    "Hyla_molleri",
    "Hyla_sarda",
    "Pelophylax_esculentus",
    "Alytes_cisternasii",
    "Pelobates_fuscus",
    "Hyla_intermedia",
    "Rana_dalmatina",
    "Pelophylax_'esculentus'",
    "Bombina_variegata",
    "Pelodytes_punctatus",
    "Pelodytes_ibericus",
    "Pelophylax_lessonae",
    "Rana_arvalis",
    "Bufotes_viridis",
    "Hyla_meridionalis",
    "Alytes_obstetricans",
    "Bombina_bombina",
    "Epidalea_calamita",
    "Pelophylax_ridibundus",
    "Hyla_arborea",
    "Pelophylax_perezi",
    "Hyla_orientalis",
    "Bufo_bufo",
    "Rana_temporaria",
}

# Ratios
train_ratio = 0.60
val_ratio   = 0.20
test_ratio  = 0.20

AUDIO_EXTS = {".wav", ".mp3"}

total_files_copied = 0

for species in sorted(target_species):
    species_folder = root / species
    if not species_folder.exists() or not species_folder.is_dir():
        print(f"[WARN] Species folder not found, skipping: {species}")
        continue

    # collect files (audio only, just in case)
    files = [f for f in species_folder.iterdir()
             if f.is_file() and f.suffix.lower() in AUDIO_EXTS]

    n = len(files)
    if n == 0:
        print(f"[INFO] No files for {species}, skipping.")
        continue

    random.shuffle(files)

    # Special case: exactly 4 recordings → 2 / 1 / 1
    if n == 4:
        n_train, n_val, n_test = 2, 1, 1
    else:
        n_train = int(n * train_ratio)
        n_val   = int(n * val_ratio)
        n_test  = n - n_train - n_val

    train_files = files[:n_train]
    val_files   = files[n_train:n_train + n_val]
    test_files  = files[n_train + n_val:]

    # Make sure species folders exist in output dirs
    (train_dir / species).mkdir(parents=True, exist_ok=True)
    (val_dir / species).mkdir(parents=True, exist_ok=True)
    (test_dir / species).mkdir(parents=True, exist_ok=True)

    # COPY files (use shutil.move if you want to move instead)
    for f in train_files:
        shutil.copy2(f, train_dir / species / f.name)
    for f in val_files:
        shutil.copy2(f, val_dir / species / f.name)
    for f in test_files:
        shutil.copy2(f, test_dir / species / f.name)

    total_files_copied += n
    print(f"{species}: total={n}, train={len(train_files)}, val={len(val_files)}, test={len(test_files)}")

print("\nDone.")
print("Total files copied:", total_files_copied)
print("Output root:", out_root)
# Out:
# Alytes_almogavarii: total=18, train=10, val=3, test=5
# Alytes_cisternasii: total=24, train=14, val=4, test=6
# Alytes_dickhilleni: total=10, train=6, val=2, test=2
# Alytes_obstetricans: total=418, train=250, val=83, test=85
# Bombina_bombina: total=585, train=351, val=117, test=117
# Bombina_variegata: total=139, train=83, val=27, test=29
# Bufo_bufo: total=246, train=147, val=49, test=50
# Bufo_spinosus: total=18, train=10, val=3, test=5
# Bufotes_viridis: total=399, train=239, val=79, test=81
# Epidalea_calamita: total=453, train=271, val=90, test=92
# Hyla_arborea: total=826, train=495, val=165, test=166
# Hyla_intermedia: total=183, train=109, val=36, test=38
# Hyla_meridionalis: total=314, train=188, val=62, test=64
# Hyla_molleri: total=44, train=26, val=8, test=10
# Hyla_orientalis: total=55, train=33, val=11, test=11
# Hyla_sarda: total=40, train=24, val=8, test=8
# Hyla_savignyi: total=12, train=7, val=2, test=3
# Lithobates_catesbeianus: total=18, train=10, val=3, test=5
# Pelobates_fuscus: total=45, train=27, val=9, test=9
# Pelodytes_atlanticus: total=14, train=8, val=2, test=4
# Pelodytes_ibericus: total=63, train=37, val=12, test=14
# Pelodytes_punctatus: total=114, train=68, val=22, test=24
# Pelophylax_'esculentus': total=90, train=54, val=18, test=18
# Pelophylax_bedriagae: total=4, train=2, val=1, test=1
# Pelophylax_esculentus: total=79, train=47, val=15, test=17
# Pelophylax_kurtmuelleri: total=28, train=16, val=5, test=7
# Pelophylax_lessonae: total=193, train=115, val=38, test=40
# Pelophylax_perezi: total=278, train=166, val=55, test=57
# Pelophylax_ridibundus: total=546, train=327, val=109, test=110
# Rana_arvalis: total=167, train=100, val=33, test=34
# Rana_dalmatina: total=89, train=53, val=17, test=19
# Rana_latastei: total=3, train=1, val=0, test=2
# Rana_temporaria: total=300, train=180, val=60, test=60
#
# Done.
# Total files copied: 5815
# Output root: /Users/jago/Desktop/naturalis/data_code/dataset_splits
